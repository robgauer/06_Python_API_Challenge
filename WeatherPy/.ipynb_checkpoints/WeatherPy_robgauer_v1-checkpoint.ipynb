# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
## HEADER COMMENTS
## Python-API-Challenge-WeatherPy-Homework
## Date Due April 18, 2020
## Author:  Rob Gauer

## FILE NAME: WeatherPy.ipynb 
## VERSION: 

## DESCRIPTION
# Part I - WeatherPy
# In this example, you'll be creating a Python script to visualize the weather of 500+ cities 
# across the world of varying distance from the equator. To accomplish this, you'll be utilizing
# a simple Python library, the OpenWeatherMap API, and a little common sense to create 
# a representative model of weather across world cities.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
import random

# Import API key
from api_keys import weather_api_key
from api_keys import g_key

# Incorporated citipy to determine city based on latitude and longitude
# Remember to validate that via pip list that citipy module is installed
from citipy import citipy

# Validate import of api_keys
print("Weather API key is:  "+ weather_api_key)
print("Google API key is:  "+ g_key)

# Read output csv file example and review requirements
#print("")
#print("cities_df Count() INFORMATION")
#print(cities_df.count())
#print("")
#cities_df.head()

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Initialization and define URL to obtain data query end-points
units="imperial"
count_loop=0
loop_set=1
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={units}&q="
#query_url="http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units={units}"
print(query_url)
# Out:
# Weather API key is:  7353f39050ebd58b7f2079c24baa85f5
# Google API key is:  AIzaSyCumrh6DyKgJ9W-WyUggsCVKko9Gbvk9b4
# http://api.openweathermap.org/data/2.5/weather?appid=7353f39050ebd58b7f2079c24baa85f5&units=imperial&q=

# %% [markdown]
# ## Generate Cities List

# %%
## GENERATE CITIES LIST
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
    
# Create a set of random lat and lng combinations
#lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
#lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lats = np.random.uniform(low=-90.000,high=90.000,size=1500)
lngs = np.random.uniform(low=-180.000,high=180.000,size=1500)
lat_lngs = zip(lats,lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city=citipy.nearest_city(lat_lng[0],lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))

# Weather dataframe formatting
city_format={"City":cities}

# Data frame to store data for cities
city_data_df=pd.DataFrame(city_format)
city_data_df
# Out:
# 624
#               City
# 0     ponta do sol
# 1        mahajanga
# 2         bien hoa
# 3     constitucion
# 4            airai
# ..             ...
# 619         calama
# 620  krasnokamensk
# 621       sulangan
# 622           gizo
# 623         bargal
#
# [624 rows x 1 columns]

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
## PERFORM API CALLS
# List for holding response values
weather_city=[]
cloudiness=[]
country=[]
date=[]
humidity=[]
lat=[]
lng=[]
max_temp=[]
wind_speed=[]

# Loop through cities by api calls to url and populate lists
for city in cities:
    try:
        print(f"Processing Record {count_loop} in Loop Set [{loop_set}|{city}")
        #response=requests.get(query_url+city).json()
        #weather_city.append(response['name'])
        response=requests.get(query_url+city.replace(" ","&")).json()
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
        if count_loop>49:
            count_loop=1
            loop_set+=1
            weather_city.append(city)
            # Add a ten second interval between queries to stay within API query limits
            time.sleep(10)
        else:
            count_loop+=1
            weather_city.append(city)
    except:
        print("")
        print("EXCEPTION: City name is not found. Skip to next city...")
        print("")
print("")
print("------------------------------Retrieval Complete------------------------------")
print("")
print("OUTPUT LISTS")
print("")
print(f"Weather City List information is:  {weather_city}")
print("")
print(f"Cloudiness List information is:  {cloudiness}")
print("")
print(f"Country List information is:  {country}")
print("")
print(f"Date List information is:  {date}")
print("")
print(f"Humidities List information is:  {humidity}")
print("")
print(f"Latitude List information is:  {lat}")
print("")
print(f"Longitude List information is:  {lng}")
print("")
print(f"Maximum Temperature List information is:  {max_temp}")
print("")
print(f"Wind Speed List information is:  {wind_speed}")
print("")
print("OUTPUT LISTS COMPLETE")
# Out:
# Processing Record 32 in Loop Set [12|ponta do sol
# Processing Record 33 in Loop Set [12|mahajanga
# Processing Record 34 in Loop Set [12|bien hoa
# Processing Record 35 in Loop Set [12|constitucion
# Processing Record 36 in Loop Set [12|airai
# Processing Record 37 in Loop Set [12|albany
# Processing Record 38 in Loop Set [12|torun
# Processing Record 39 in Loop Set [12|butaritari
# Processing Record 40 in Loop Set [12|kyabe
# Processing Record 41 in Loop Set [12|yaring
# Processing Record 42 in Loop Set [12|richards bay
# Processing Record 43 in Loop Set [12|yulara
# Processing Record 44 in Loop Set [12|yellowknife
# Processing Record 45 in Loop Set [12|illoqqortoormiut
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 45 in Loop Set [12|punta arenas
# Processing Record 46 in Loop Set [12|surgut
# Processing Record 47 in Loop Set [12|freeport
# Processing Record 48 in Loop Set [12|kahului
# Processing Record 49 in Loop Set [12|barrow
# Processing Record 50 in Loop Set [12|liverpool
# Processing Record 1 in Loop Set [13|broome
# Processing Record 2 in Loop Set [13|hobart
# Processing Record 3 in Loop Set [13|rikitea
# Processing Record 4 in Loop Set [13|bengkulu
# Processing Record 5 in Loop Set [13|bethel
# Processing Record 6 in Loop Set [13|beringovskiy
# Processing Record 7 in Loop Set [13|asau
# Processing Record 8 in Loop Set [13|lumut
# Processing Record 9 in Loop Set [13|portland
# Processing Record 10 in Loop Set [13|sampit
# Processing Record 11 in Loop Set [13|severobaykalsk
# Processing Record 12 in Loop Set [13|nikolskoye
# Processing Record 13 in Loop Set [13|grand centre
# Processing Record 14 in Loop Set [13|port alfred
# Processing Record 15 in Loop Set [13|sisimiut
# Processing Record 16 in Loop Set [13|bathsheba
# Processing Record 17 in Loop Set [13|lorengau
# Processing Record 18 in Loop Set [13|busselton
# Processing Record 19 in Loop Set [13|tuktoyaktuk
# Processing Record 20 in Loop Set [13|ocampo
# Processing Record 21 in Loop Set [13|chifeng
# Processing Record 22 in Loop Set [13|anloga
# Processing Record 23 in Loop Set [13|davila
# Processing Record 24 in Loop Set [13|vila franca do campo
# Processing Record 25 in Loop Set [13|grand river south east
# Processing Record 26 in Loop Set [13|jamestown
# Processing Record 27 in Loop Set [13|mayo
# Processing Record 28 in Loop Set [13|haines junction
# Processing Record 29 in Loop Set [13|persan
# Processing Record 30 in Loop Set [13|taoudenni
# Processing Record 31 in Loop Set [13|georgetown
# Processing Record 32 in Loop Set [13|touros
# Processing Record 33 in Loop Set [13|puerto ayora
# Processing Record 34 in Loop Set [13|ushuaia
# Processing Record 35 in Loop Set [13|bredasdorp
# Processing Record 36 in Loop Set [13|xining
# Processing Record 37 in Loop Set [13|ribeira grande
# Processing Record 38 in Loop Set [13|libreville
# Processing Record 39 in Loop Set [13|batagay
# Processing Record 40 in Loop Set [13|tigil
# Processing Record 41 in Loop Set [13|mackenzie
# Processing Record 42 in Loop Set [13|iqaluit
# Processing Record 43 in Loop Set [13|east london
# Processing Record 44 in Loop Set [13|kidal
# Processing Record 45 in Loop Set [13|umtata
# Processing Record 46 in Loop Set [13|pevek
# Processing Record 47 in Loop Set [13|hithadhoo
# Processing Record 48 in Loop Set [13|longyearbyen
# Processing Record 49 in Loop Set [13|kapaa
# Processing Record 50 in Loop Set [13|guerrero negro
# Processing Record 1 in Loop Set [14|melita
# Processing Record 2 in Loop Set [14|hamilton
# Processing Record 3 in Loop Set [14|new norfolk
# Processing Record 4 in Loop Set [14|nanortalik
# Processing Record 5 in Loop Set [14|komsomolskiy
# Processing Record 6 in Loop Set [14|belmonte
# Processing Record 7 in Loop Set [14|labrea
# Processing Record 8 in Loop Set [14|flinders
# Processing Record 9 in Loop Set [14|port elizabeth
# Processing Record 10 in Loop Set [14|sao felix do xingu
# Processing Record 11 in Loop Set [14|bluff
# Processing Record 12 in Loop Set [14|sharkan
# Processing Record 13 in Loop Set [14|huari
# Processing Record 14 in Loop Set [14|phayao
# Processing Record 15 in Loop Set [14|gat
# Processing Record 16 in Loop Set [14|cao bang
# Processing Record 17 in Loop Set [14|dese
# Processing Record 18 in Loop Set [14|mataura
# Processing Record 19 in Loop Set [14|temaraia
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 19 in Loop Set [14|atuona
# Processing Record 20 in Loop Set [14|vilhena
# Processing Record 21 in Loop Set [14|vinukonda
# Processing Record 22 in Loop Set [14|kamenskoye
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 22 in Loop Set [14|avarua
# Processing Record 23 in Loop Set [14|pinar del rio
# Processing Record 24 in Loop Set [14|porto seguro
# Processing Record 25 in Loop Set [14|thompson
# Processing Record 26 in Loop Set [14|vaini
# Processing Record 27 in Loop Set [14|yuxia
# Processing Record 28 in Loop Set [14|tual
# Processing Record 29 in Loop Set [14|hermanus
# Processing Record 30 in Loop Set [14|byron bay
# Processing Record 31 in Loop Set [14|cape town
# Processing Record 32 in Loop Set [14|qaanaaq
# Processing Record 33 in Loop Set [14|goderich
# Processing Record 34 in Loop Set [14|faanui
# Processing Record 35 in Loop Set [14|castro
# Processing Record 36 in Loop Set [14|namibe
# Processing Record 37 in Loop Set [14|sinnamary
# Processing Record 38 in Loop Set [14|cherskiy
# Processing Record 39 in Loop Set [14|shelopugino
# Processing Record 40 in Loop Set [14|cayenne
# Processing Record 41 in Loop Set [14|narsaq
# Processing Record 42 in Loop Set [14|saint george
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 42 in Loop Set [14|fortuna
# Processing Record 43 in Loop Set [14|tidore
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 43 in Loop Set [14|tilichiki
# Processing Record 44 in Loop Set [14|podgornoye
# Processing Record 45 in Loop Set [14|newport
# Processing Record 46 in Loop Set [14|lewiston
# Processing Record 47 in Loop Set [14|aklavik
# Processing Record 48 in Loop Set [14|lagoa
# Processing Record 49 in Loop Set [14|harrison
# Processing Record 50 in Loop Set [14|pastavy
# Processing Record 1 in Loop Set [15|attawapiskat
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 1 in Loop Set [15|chokurdakh
# Processing Record 2 in Loop Set [15|nemuro
# Processing Record 3 in Loop Set [15|taolanaro
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 3 in Loop Set [15|itapirapua
# Processing Record 4 in Loop Set [15|seoul
# Processing Record 5 in Loop Set [15|lebu
# Processing Record 6 in Loop Set [15|bera
# Processing Record 7 in Loop Set [15|qui nhon
# Processing Record 8 in Loop Set [15|carnarvon
# Processing Record 9 in Loop Set [15|tumannyy
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 9 in Loop Set [15|te anau
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 9 in Loop Set [15|kwakoa
# Processing Record 10 in Loop Set [15|matara
# Processing Record 11 in Loop Set [15|kolpashevo
# Processing Record 12 in Loop Set [15|koka
# Processing Record 13 in Loop Set [15|saint-philippe
# Processing Record 14 in Loop Set [15|egvekinot
# Processing Record 15 in Loop Set [15|geraldton
# Processing Record 16 in Loop Set [15|nome
# Processing Record 17 in Loop Set [15|saint anthony
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 17 in Loop Set [15|riverton
# Processing Record 18 in Loop Set [15|port antonio
# Processing Record 19 in Loop Set [15|alofi
# Processing Record 20 in Loop Set [15|roald
# Processing Record 21 in Loop Set [15|hope
# Processing Record 22 in Loop Set [15|gulshat
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 22 in Loop Set [15|ust-kuyga
# Processing Record 23 in Loop Set [15|kerouane
# Processing Record 24 in Loop Set [15|omsukchan
# Processing Record 25 in Loop Set [15|tasiilaq
# Processing Record 26 in Loop Set [15|barentsburg
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 26 in Loop Set [15|penzance
# Processing Record 27 in Loop Set [15|tiarei
# Processing Record 28 in Loop Set [15|telde
# Processing Record 29 in Loop Set [15|sao joao da barra
# Processing Record 30 in Loop Set [15|sokolka
# Processing Record 31 in Loop Set [15|arraial do cabo
# Processing Record 32 in Loop Set [15|victoria
# Processing Record 33 in Loop Set [15|khatanga
# Processing Record 34 in Loop Set [15|saldanha
# Processing Record 35 in Loop Set [15|grindavik
# Processing Record 36 in Loop Set [15|san antonio
# Processing Record 37 in Loop Set [15|verkhnyaya inta
# Processing Record 38 in Loop Set [15|ostrovnoy
# Processing Record 39 in Loop Set [15|andenes
# Processing Record 40 in Loop Set [15|harper
# Processing Record 41 in Loop Set [15|mar del plata
# Processing Record 42 in Loop Set [15|kinel
# Processing Record 43 in Loop Set [15|belushya guba
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 43 in Loop Set [15|zhigansk
# Processing Record 44 in Loop Set [15|palabuhanratu
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 44 in Loop Set [15|george
# Processing Record 45 in Loop Set [15|danshui
# Processing Record 46 in Loop Set [15|sitka
# Processing Record 47 in Loop Set [15|jalu
# Processing Record 48 in Loop Set [15|takoradi
# Processing Record 49 in Loop Set [15|lavrentiya
# Processing Record 50 in Loop Set [15|torbay
# Processing Record 1 in Loop Set [16|souillac
# Processing Record 2 in Loop Set [16|cidreira
# Processing Record 3 in Loop Set [16|hilo
# Processing Record 4 in Loop Set [16|bautzen
# Processing Record 5 in Loop Set [16|auki
# Processing Record 6 in Loop Set [16|los llanos de aridane
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 6 in Loop Set [16|culpeper
# Processing Record 7 in Loop Set [16|clinton
# Processing Record 8 in Loop Set [16|baboua
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 8 in Loop Set [16|kemi
# Processing Record 9 in Loop Set [16|kaitangata
# Processing Record 10 in Loop Set [16|margherita di savoia
# Processing Record 11 in Loop Set [16|havoysund
# Processing Record 12 in Loop Set [16|munsingen
# Processing Record 13 in Loop Set [16|mahebourg
# Processing Record 14 in Loop Set [16|tres arroyos
# Processing Record 15 in Loop Set [16|chapais
# Processing Record 16 in Loop Set [16|saint-jerome
# Processing Record 17 in Loop Set [16|kruisfontein
# Processing Record 18 in Loop Set [16|kupang
# Processing Record 19 in Loop Set [16|ust-barguzin
# Processing Record 20 in Loop Set [16|mariinskiy posad
# Processing Record 21 in Loop Set [16|mana
# Processing Record 22 in Loop Set [16|aporawan
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 22 in Loop Set [16|penuelas
# Processing Record 23 in Loop Set [16|bumba
# Processing Record 24 in Loop Set [16|palmer
# Processing Record 25 in Loop Set [16|saskylakh
# Processing Record 26 in Loop Set [16|sentyabrskiy
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 26 in Loop Set [16|dicabisagan
# Processing Record 27 in Loop Set [16|pavlodar
# Processing Record 28 in Loop Set [16|dikson
# Processing Record 29 in Loop Set [16|port hardy
# Processing Record 30 in Loop Set [16|zinder
# Processing Record 31 in Loop Set [16|sao sebastiao do paraiso
# Processing Record 32 in Loop Set [16|puerto quijarro
# Processing Record 33 in Loop Set [16|berlevag
# Processing Record 34 in Loop Set [16|la ronge
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 34 in Loop Set [16|krasnoselkup
# Processing Record 35 in Loop Set [16|upernavik
# Processing Record 36 in Loop Set [16|fairmont
# Processing Record 37 in Loop Set [16|sutysky
# Processing Record 38 in Loop Set [16|itarema
# Processing Record 39 in Loop Set [16|clyde river
# Processing Record 40 in Loop Set [16|del rio
# Processing Record 41 in Loop Set [16|arlit
# Processing Record 42 in Loop Set [16|hovd
# Processing Record 43 in Loop Set [16|borogontsy
# Processing Record 44 in Loop Set [16|cabo san lucas
# Processing Record 45 in Loop Set [16|tuatapere
# Processing Record 46 in Loop Set [16|nizhneyansk
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 46 in Loop Set [16|ambanja
# Processing Record 47 in Loop Set [16|mys shmidta
# Processing Record 48 in Loop Set [16|saint-ambroise
# Processing Record 49 in Loop Set [16|cabinda
# Processing Record 50 in Loop Set [16|tabas
# Processing Record 1 in Loop Set [17|kargopol
# Processing Record 2 in Loop Set [17|bilibino
# Processing Record 3 in Loop Set [17|kirakira
# Processing Record 4 in Loop Set [17|douglas
# Processing Record 5 in Loop Set [17|tautira
# Processing Record 6 in Loop Set [17|the valley
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 6 in Loop Set [17|kawerau
# Processing Record 7 in Loop Set [17|fort nelson
# Processing Record 8 in Loop Set [17|mandalgovi
# Processing Record 9 in Loop Set [17|bandarbeyla
# Processing Record 10 in Loop Set [17|sorvag
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 10 in Loop Set [17|sept-iles
# Processing Record 11 in Loop Set [17|vila
# Processing Record 12 in Loop Set [17|ovre ardal
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 12 in Loop Set [17|coahuayana
# Processing Record 13 in Loop Set [17|hofn
# Processing Record 14 in Loop Set [17|meulaboh
# Processing Record 15 in Loop Set [17|rio gallegos
# Processing Record 16 in Loop Set [17|suraabad
# Processing Record 17 in Loop Set [17|talnakh
# Processing Record 18 in Loop Set [17|kasempa
# Processing Record 19 in Loop Set [17|banda aceh
# Processing Record 20 in Loop Set [17|hualmay
# Processing Record 21 in Loop Set [17|praia da vitoria
# Processing Record 22 in Loop Set [17|mildura
# Processing Record 23 in Loop Set [17|ishigaki
# Processing Record 24 in Loop Set [17|hokitika
# Processing Record 25 in Loop Set [17|wattegama
# Processing Record 26 in Loop Set [17|camacha
# Processing Record 27 in Loop Set [17|tsihombe
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 27 in Loop Set [17|basco
# Processing Record 28 in Loop Set [17|ilhabela
# Processing Record 29 in Loop Set [17|lasa
# Processing Record 30 in Loop Set [17|hasaki
# Processing Record 31 in Loop Set [17|leningradskiy
# Processing Record 32 in Loop Set [17|jaisalmer
# Processing Record 33 in Loop Set [17|boyolangu
# Processing Record 34 in Loop Set [17|dingle
# Processing Record 35 in Loop Set [17|samarai
# Processing Record 36 in Loop Set [17|laguna
# Processing Record 37 in Loop Set [17|conde
# Processing Record 38 in Loop Set [17|cuamba
# Processing Record 39 in Loop Set [17|diu
# Processing Record 40 in Loop Set [17|sechura
# Processing Record 41 in Loop Set [17|grants
# Processing Record 42 in Loop Set [17|altay
# Processing Record 43 in Loop Set [17|maumelle
# Processing Record 44 in Loop Set [17|kribi
# Processing Record 45 in Loop Set [17|norman wells
# Processing Record 46 in Loop Set [17|nurota
# Processing Record 47 in Loop Set [17|esperance
# Processing Record 48 in Loop Set [17|saint-denis
# Processing Record 49 in Loop Set [17|shakawe
# Processing Record 50 in Loop Set [17|cowra
# Processing Record 1 in Loop Set [18|phimai
# Processing Record 2 in Loop Set [18|severo-kurilsk
# Processing Record 3 in Loop Set [18|amderma
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 3 in Loop Set [18|cockburn harbour
# Processing Record 4 in Loop Set [18|puri
# Processing Record 5 in Loop Set [18|ayagoz
# Processing Record 6 in Loop Set [18|benguela
# Processing Record 7 in Loop Set [18|boa vista
# Processing Record 8 in Loop Set [18|bikin
# Processing Record 9 in Loop Set [18|kazalinsk
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 9 in Loop Set [18|juneau
# Processing Record 10 in Loop Set [18|paamiut
# Processing Record 11 in Loop Set [18|sungaipenuh
# Processing Record 12 in Loop Set [18|san patricio
# Processing Record 13 in Loop Set [18|waipawa
# Processing Record 14 in Loop Set [18|san cristobal
# Processing Record 15 in Loop Set [18|namatanai
# Processing Record 16 in Loop Set [18|pasighat
# Processing Record 17 in Loop Set [18|adrar
# Processing Record 18 in Loop Set [18|sioux lookout
# Processing Record 19 in Loop Set [18|la romana
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 19 in Loop Set [18|iraan
# Processing Record 20 in Loop Set [18|kurchum
# Processing Record 21 in Loop Set [18|hommelvik
# Processing Record 22 in Loop Set [18|bartica
# Processing Record 23 in Loop Set [18|anadyr
# Processing Record 24 in Loop Set [18|hasilpur
# Processing Record 25 in Loop Set [18|usinsk
# Processing Record 26 in Loop Set [18|sambava
# Processing Record 27 in Loop Set [18|bosaso
# Processing Record 28 in Loop Set [18|honnali
# Processing Record 29 in Loop Set [18|tulsipur
# Processing Record 30 in Loop Set [18|okato
# Processing Record 31 in Loop Set [18|kizema
# Processing Record 32 in Loop Set [18|lipari
# Processing Record 33 in Loop Set [18|sangmelima
# Processing Record 34 in Loop Set [18|kudahuvadhoo
# Processing Record 35 in Loop Set [18|guayaramerin
# Processing Record 36 in Loop Set [18|necochea
# Processing Record 37 in Loop Set [18|vitim
# Processing Record 38 in Loop Set [18|tsiroanomandidy
# Processing Record 39 in Loop Set [18|alice springs
# Processing Record 40 in Loop Set [18|vsevolodo-vilva
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 40 in Loop Set [18|hambantota
# Processing Record 41 in Loop Set [18|roros
# Processing Record 42 in Loop Set [18|deputatskiy
# Processing Record 43 in Loop Set [18|pervomayskoye
# Processing Record 44 in Loop Set [18|magnitogorsk
# Processing Record 45 in Loop Set [18|santa vitoria do palmar
# Processing Record 46 in Loop Set [18|buarcos
# Processing Record 47 in Loop Set [18|erenhot
# Processing Record 48 in Loop Set [18|ortigueira
# Processing Record 49 in Loop Set [18|baykalsk
# Processing Record 50 in Loop Set [18|yashkul
# Processing Record 1 in Loop Set [19|port moresby
# Processing Record 2 in Loop Set [19|thinadhoo
# Processing Record 3 in Loop Set [19|bellavista
# Processing Record 4 in Loop Set [19|ponta delgada
# Processing Record 5 in Loop Set [19|mazagao
# Processing Record 6 in Loop Set [19|merke
# Processing Record 7 in Loop Set [19|prabumulih
# Processing Record 8 in Loop Set [19|sao gabriel da cachoeira
# Processing Record 9 in Loop Set [19|tarnow
# Processing Record 10 in Loop Set [19|husavik
# Processing Record 11 in Loop Set [19|salvador
# Processing Record 12 in Loop Set [19|nampula
# Processing Record 13 in Loop Set [19|jerome
# Processing Record 14 in Loop Set [19|codrington
# Processing Record 15 in Loop Set [19|malm
# Processing Record 16 in Loop Set [19|trn
# Processing Record 17 in Loop Set [19|pekalongan
# Processing Record 18 in Loop Set [19|howard springs
# Processing Record 19 in Loop Set [19|ilulissat
# Processing Record 20 in Loop Set [19|plettenberg bay
# Processing Record 21 in Loop Set [19|oum hadjer
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 21 in Loop Set [19|cabanas
# Processing Record 22 in Loop Set [19|beloha
# Processing Record 23 in Loop Set [19|bafq
# Processing Record 24 in Loop Set [19|cockburn town
# Processing Record 25 in Loop Set [19|tazirkah
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 25 in Loop Set [19|luderitz
# Processing Record 26 in Loop Set [19|zolotinka
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 26 in Loop Set [19|mackay
# Processing Record 27 in Loop Set [19|kenitra
# Processing Record 28 in Loop Set [19|verkhnevilyuysk
# Processing Record 29 in Loop Set [19|mount gambier
# Processing Record 30 in Loop Set [19|comodoro rivadavia
# Processing Record 31 in Loop Set [19|kloulklubed
# Processing Record 32 in Loop Set [19|anaconda
# Processing Record 33 in Loop Set [19|chara
# Processing Record 34 in Loop Set [19|staryy nadym
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 34 in Loop Set [19|nantucket
# Processing Record 35 in Loop Set [19|booue
# Processing Record 36 in Loop Set [19|gao
# Processing Record 37 in Loop Set [19|christchurch
# Processing Record 38 in Loop Set [19|pauini
# Processing Record 39 in Loop Set [19|svarstad
# Processing Record 40 in Loop Set [19|leshukonskoye
# Processing Record 41 in Loop Set [19|korla
# Processing Record 42 in Loop Set [19|male
# Processing Record 43 in Loop Set [19|lolua
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 43 in Loop Set [19|ngukurr
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 43 in Loop Set [19|talawdi
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 43 in Loop Set [19|keti bandar
# Processing Record 44 in Loop Set [19|taclobo
# Processing Record 45 in Loop Set [19|padang
# Processing Record 46 in Loop Set [19|san felipe
# Processing Record 47 in Loop Set [19|pahrump
# Processing Record 48 in Loop Set [19|naze
# Processing Record 49 in Loop Set [19|port augusta
# Processing Record 50 in Loop Set [19|tapes
# Processing Record 1 in Loop Set [20|marsh harbour
# Processing Record 2 in Loop Set [20|mount hagen
# Processing Record 3 in Loop Set [20|sibolga
# Processing Record 4 in Loop Set [20|noumea
# Processing Record 5 in Loop Set [20|chuy
# Processing Record 6 in Loop Set [20|batemans bay
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 6 in Loop Set [20|manavalakurichi
# Processing Record 7 in Loop Set [20|brooks
# Processing Record 8 in Loop Set [20|dvurechensk
# Processing Record 9 in Loop Set [20|baykit
# Processing Record 10 in Loop Set [20|nioro
# Processing Record 11 in Loop Set [20|omboue
# Processing Record 12 in Loop Set [20|mabai
# Processing Record 13 in Loop Set [20|san policarpo
# Processing Record 14 in Loop Set [20|bowen
# Processing Record 15 in Loop Set [20|tateyama
# Processing Record 16 in Loop Set [20|kesova gora
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 16 in Loop Set [20|vanimo
# Processing Record 17 in Loop Set [20|vostok
# Processing Record 18 in Loop Set [20|vryburg
# Processing Record 19 in Loop Set [20|seryshevo
# Processing Record 20 in Loop Set [20|svobodnyy
# Processing Record 21 in Loop Set [20|porto santo
# Processing Record 22 in Loop Set [20|mikuni
# Processing Record 23 in Loop Set [20|eskasem
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 23 in Loop Set [20|bambous virieux
# Processing Record 24 in Loop Set [20|kodiak
# Processing Record 25 in Loop Set [20|jacareacanga
# Processing Record 26 in Loop Set [20|ozgon
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 26 in Loop Set [20|coihaique
# Processing Record 27 in Loop Set [20|lompoc
# Processing Record 28 in Loop Set [20|klaksvik
# Processing Record 29 in Loop Set [20|bereda
# Processing Record 30 in Loop Set [20|falmouth
# Processing Record 31 in Loop Set [20|ventspils
# Processing Record 32 in Loop Set [20|oudtshoorn
# Processing Record 33 in Loop Set [20|benton harbor
# Processing Record 34 in Loop Set [20|isangel
# Processing Record 35 in Loop Set [20|jacqueville
# Processing Record 36 in Loop Set [20|hami
# Processing Record 37 in Loop Set [20|sijunjung
# Processing Record 38 in Loop Set [20|aleksandrov gay
# Processing Record 39 in Loop Set [20|punta cardon
# Processing Record 40 in Loop Set [20|koslan
# Processing Record 41 in Loop Set [20|batagay-alyta
# Processing Record 42 in Loop Set [20|buraydah
# Processing Record 43 in Loop Set [20|siemiatycze
# Processing Record 44 in Loop Set [20|weston
# Processing Record 45 in Loop Set [20|bethanien
# Processing Record 46 in Loop Set [20|gwadar
# Processing Record 47 in Loop Set [20|hailar
# Processing Record 48 in Loop Set [20|aflu
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 48 in Loop Set [20|salalah
# Processing Record 49 in Loop Set [20|lakes entrance
# Processing Record 50 in Loop Set [20|nizwa
# Processing Record 1 in Loop Set [21|kalmunai
# Processing Record 2 in Loop Set [21|smirnykh
# Processing Record 3 in Loop Set [21|acarau
# Processing Record 4 in Loop Set [21|caravelas
# Processing Record 5 in Loop Set [21|college
# Processing Record 6 in Loop Set [21|satitoa
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 6 in Loop Set [21|kurumkan
# Processing Record 7 in Loop Set [21|halifax
# Processing Record 8 in Loop Set [21|petauke
# Processing Record 9 in Loop Set [21|olafsvik
# Processing Record 10 in Loop Set [21|sirjan
# Processing Record 11 in Loop Set [21|sao jose da coroa grande
# Processing Record 12 in Loop Set [21|salinas
# Processing Record 13 in Loop Set [21|lodwar
# Processing Record 14 in Loop Set [21|bowling green
# Processing Record 15 in Loop Set [21|bahia de caraquez
# Processing Record 16 in Loop Set [21|cheney
# Processing Record 17 in Loop Set [21|ust-maya
# Processing Record 18 in Loop Set [21|praia
# Processing Record 19 in Loop Set [21|kharan
# Processing Record 20 in Loop Set [21|atsiki
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 20 in Loop Set [21|maningrida
# Processing Record 21 in Loop Set [21|petropavlovsk-kamchatskiy
# Processing Record 22 in Loop Set [21|terney
# Processing Record 23 in Loop Set [21|pitsunda
# Processing Record 24 in Loop Set [21|aykhal
# Processing Record 25 in Loop Set [21|zambezi
# Processing Record 26 in Loop Set [21|mizdah
# Processing Record 27 in Loop Set [21|destin
# Processing Record 28 in Loop Set [21|acapulco
# Processing Record 29 in Loop Set [21|yar-sale
# Processing Record 30 in Loop Set [21|ribeira brava
# Processing Record 31 in Loop Set [21|margate
# Processing Record 32 in Loop Set [21|canutama
# Processing Record 33 in Loop Set [21|kingman
# Processing Record 34 in Loop Set [21|dvinskoy
# Processing Record 35 in Loop Set [21|port lincoln
# Processing Record 36 in Loop Set [21|port hedland
# Processing Record 37 in Loop Set [21|baoro
# Processing Record 38 in Loop Set [21|tanout
# Processing Record 39 in Loop Set [21|rondonopolis
# Processing Record 40 in Loop Set [21|fernandina beach
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 40 in Loop Set [21|saleaula
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 40 in Loop Set [21|ermelo
# Processing Record 41 in Loop Set [21|antsirabe
# Processing Record 42 in Loop Set [21|mikkeli
# Processing Record 43 in Loop Set [21|pakxan
# Processing Record 44 in Loop Set [21|adamov
# Processing Record 45 in Loop Set [21|goya
# Processing Record 46 in Loop Set [21|tabuk
# Processing Record 47 in Loop Set [21|vardo
# Processing Record 48 in Loop Set [21|balakhninskiy
# Processing Record 49 in Loop Set [21|malakal
# Processing Record 50 in Loop Set [21|sao borja
# Processing Record 1 in Loop Set [22|coquimbo
# Processing Record 2 in Loop Set [22|vestmanna
# Processing Record 3 in Loop Set [22|dhule
# Processing Record 4 in Loop Set [22|aldan
# Processing Record 5 in Loop Set [22|kaitong
# Processing Record 6 in Loop Set [22|haguenau
# Processing Record 7 in Loop Set [22|samarkand
# Processing Record 8 in Loop Set [22|sembakung
# Processing Record 9 in Loop Set [22|polyarnyy
# Processing Record 10 in Loop Set [22|tadepalle
# Processing Record 11 in Loop Set [22|kamensk-uralskiy
# Processing Record 12 in Loop Set [22|bozova
# Processing Record 13 in Loop Set [22|mananara
# Processing Record 14 in Loop Set [22|pushkinskiye gory
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 14 in Loop Set [22|fukue
# Processing Record 15 in Loop Set [22|pochutla
# Processing Record 16 in Loop Set [22|fairview
# Processing Record 17 in Loop Set [22|port hawkesbury
# Processing Record 18 in Loop Set [22|labuhan
# Processing Record 19 in Loop Set [22|estelle
# Processing Record 20 in Loop Set [22|fairbanks
# Processing Record 21 in Loop Set [22|arieseni
# Processing Record 22 in Loop Set [22|nuuk
# Processing Record 23 in Loop Set [22|celestun
# Processing Record 24 in Loop Set [22|rivadavia
# Processing Record 25 in Loop Set [22|kavieng
# Processing Record 26 in Loop Set [22|vaitupu
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 26 in Loop Set [22|fougamou
# Processing Record 27 in Loop Set [22|rosarito
# Processing Record 28 in Loop Set [22|amambai
# Processing Record 29 in Loop Set [22|oak harbor
# Processing Record 30 in Loop Set [22|umzimvubu
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 30 in Loop Set [22|at-bashi
# Processing Record 31 in Loop Set [22|bajil
# Processing Record 32 in Loop Set [22|avera
# Processing Record 33 in Loop Set [22|shimoda
# Processing Record 34 in Loop Set [22|darnah
# Processing Record 35 in Loop Set [22|vari
# Processing Record 36 in Loop Set [22|bandipur
# Processing Record 37 in Loop Set [22|nowa sol
# Processing Record 38 in Loop Set [22|guymon
# Processing Record 39 in Loop Set [22|ambikapur
# Processing Record 40 in Loop Set [22|kiama
# Processing Record 41 in Loop Set [22|huarmey
# Processing Record 42 in Loop Set [22|ambon
# Processing Record 43 in Loop Set [22|cavan
# Processing Record 44 in Loop Set [22|acari
# Processing Record 45 in Loop Set [22|trondheim
# Processing Record 46 in Loop Set [22|pinega
# Processing Record 47 in Loop Set [22|erzin
# Processing Record 48 in Loop Set [22|san joaquin
# Processing Record 49 in Loop Set [22|tacuati
# Processing Record 50 in Loop Set [22|taitung
# Processing Record 1 in Loop Set [23|buchanan
# Processing Record 2 in Loop Set [23|ankazoabo
# Processing Record 3 in Loop Set [23|san pedro
# Processing Record 4 in Loop Set [23|wewak
# Processing Record 5 in Loop Set [23|altamont
# Processing Record 6 in Loop Set [23|graaff-reinet
# Processing Record 7 in Loop Set [23|okhotsk
# Processing Record 8 in Loop Set [23|uddevalla
# Processing Record 9 in Loop Set [23|poum
# Processing Record 10 in Loop Set [23|vestmannaeyjar
# Processing Record 11 in Loop Set [23|caconda
# Processing Record 12 in Loop Set [23|marcona
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 12 in Loop Set [23|qujing
# Processing Record 13 in Loop Set [23|hobyo
# Processing Record 14 in Loop Set [23|miyako
# Processing Record 15 in Loop Set [23|dillon
# Processing Record 16 in Loop Set [23|langsa
# Processing Record 17 in Loop Set [23|whitianga
# Processing Record 18 in Loop Set [23|lahaina
# Processing Record 19 in Loop Set [23|bluefields
# Processing Record 20 in Loop Set [23|okha
# Processing Record 21 in Loop Set [23|dongfeng
# Processing Record 22 in Loop Set [23|terenga
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 22 in Loop Set [23|la libertad
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 22 in Loop Set [23|baghdad
# Processing Record 23 in Loop Set [23|luena
# Processing Record 24 in Loop Set [23|osa
# Processing Record 25 in Loop Set [23|ust-tsilma
# Processing Record 26 in Loop Set [23|manicore
# Processing Record 27 in Loop Set [23|shunyi
# Processing Record 28 in Loop Set [23|tucuman
# Processing Record 29 in Loop Set [23|rassvet
# Processing Record 30 in Loop Set [23|oktyabrskoye
# Processing Record 31 in Loop Set [23|halalo
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 31 in Loop Set [23|madras
# Processing Record 32 in Loop Set [23|vilyuysk
# Processing Record 33 in Loop Set [23|upata
# Processing Record 34 in Loop Set [23|cavalcante
# Processing Record 35 in Loop Set [23|kavaratti
# Processing Record 36 in Loop Set [23|kyra
# Processing Record 37 in Loop Set [23|gigmoto
# Processing Record 38 in Loop Set [23|emerald
# Processing Record 39 in Loop Set [23|aloleng
# Processing Record 40 in Loop Set [23|belen
# Processing Record 41 in Loop Set [23|kapasan
# Processing Record 42 in Loop Set [23|brae
# Processing Record 43 in Loop Set [23|boysun
# Processing Record 44 in Loop Set [23|seymchan
# Processing Record 45 in Loop Set [23|qianan
# Processing Record 46 in Loop Set [23|burica
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 46 in Loop Set [23|mount isa
# Processing Record 47 in Loop Set [23|camrose
# Processing Record 48 in Loop Set [23|pisco
# Processing Record 49 in Loop Set [23|calama
# Processing Record 50 in Loop Set [23|krasnokamensk
# Processing Record 1 in Loop Set [24|sulangan
# Processing Record 2 in Loop Set [24|gizo
# Processing Record 3 in Loop Set [24|bargal
#
# EXCEPTION: City name is not found. Skip to next city...
#
#
# ------------------------------Retrieval Complete------------------------------
#
# OUTPUT LISTS
#
# Weather City List information is:  ['ponta do sol', 'mahajanga', 'bien hoa', 'constitucion', 'airai', 'albany', 'torun', 'butaritari', 'kyabe', 'yaring', 'richards bay', 'yulara', 'yellowknife', 'punta arenas', 'surgut', 'freeport', 'kahului', 'barrow', 'liverpool', 'broome', 'hobart', 'rikitea', 'bengkulu', 'bethel', 'beringovskiy', 'asau', 'lumut', 'portland', 'sampit', 'severobaykalsk', 'nikolskoye', 'grand centre', 'port alfred', 'sisimiut', 'bathsheba', 'lorengau', 'busselton', 'tuktoyaktuk', 'ocampo', 'chifeng', 'anloga', 'davila', 'vila franca do campo', 'grand river south east', 'jamestown', 'mayo', 'haines junction', 'persan', 'taoudenni', 'georgetown', 'touros', 'puerto ayora', 'ushuaia', 'bredasdorp', 'xining', 'ribeira grande', 'libreville', 'batagay', 'tigil', 'mackenzie', 'iqaluit', 'east london', 'kidal', 'umtata', 'pevek', 'hithadhoo', 'longyearbyen', 'kapaa', 'guerrero negro', 'melita', 'hamilton', 'new norfolk', 'nanortalik', 'komsomolskiy', 'belmonte', 'labrea', 'flinders', 'port elizabeth', 'sao felix do xingu', 'bluff', 'sharkan', 'huari', 'phayao', 'gat', 'cao bang', 'dese', 'mataura', 'atuona', 'vilhena', 'vinukonda', 'avarua', 'pinar del rio', 'porto seguro', 'thompson', 'vaini', 'yuxia', 'tual', 'hermanus', 'byron bay', 'cape town', 'qaanaaq', 'goderich', 'faanui', 'castro', 'namibe', 'sinnamary', 'cherskiy', 'shelopugino', 'cayenne', 'narsaq', 'fortuna', 'tilichiki', 'podgornoye', 'newport', 'lewiston', 'aklavik', 'l
93, 6.24, 8.05, 8.19, 6.71, 2.53, 7.7, 2.51, 7.4, 12.41, 10.42, 6.93, 6.46, 6.2, 9.78, 5.82, 8.97, 17.22, 5.82, 18.34, 0.85, 0.74, 4.05, 4.9, 9.06, 8.05, 11.41, 17.22, 2.24, 5.99, 14.88, 8.05, 3.94, 1.36, 13.53, 6.15, 14.16, 20.38, 18.34, 3, 5.01, 4.03, 6.15, 7.49, 6.93, 0.83, 6.58, 7.34, 7.47, 5.66, 7.78, 1.57, 4, 4.25, 4, 18.86, 2.3, 9.82, 3.91, 15.12, 6.93, 3.49, 3.96, 6.26, 17.22, 13.02, 10.31, 13.42, 9.53, 4.47, 6.71, 4.83, 9.26, 4, 2.53, 22.32, 10.29, 13.87, 2.57, 3, 9.08, 9.24, 9.24, 4.92, 7.83, 2.8, 6.4, 4, 13.87, 5.88, 1.12, 3.42, 7.29, 25.28, 8.55, 11.16, 9.82, 8.05, 7.85, 13.09, 11.68, 10.33, 3.36, 2.24, 6.17, 6.71, 3.36, 9.33, 9.17, 13.15, 16.11, 5.39, 1.99, 9.24, 7.16, 8.28, 1.7, 0.56, 9.01, 14.47, 3.36, 13.04, 1.88, 4.25, 4.36, 13.96, 2.28, 4.29, 4.9, 6.93, 15.7, 1.12, 4.76, 1.23, 20.87, 7.47, 3, 6.55, 3.51, 8.01, 4.12, 19.46, 3.74, 4.7, 12.41, 3.13, 11.41, 5.41, 5.37, 12.41, 8.72, 11.99, 1.01, 9.44, 4.7, 12.35, 14.14, 2.66, 20.07, 13.35, 9.24, 2.21, 5.14, 8.01, 10, 7.07, 12.41, 13.13, 5.82, 3.22, 14.83, 10.78, 0.65, 11.18, 9.17, 26.96, 4.47, 8.05, 11.68, 4.09, 4, 4.38, 7.92, 12.35, 5.01, 9.84, 4.7, 5.77, 4.03, 2.64, 14.7, 8.81, 2.24, 3, 5.99, 16.11, 9.17, 6.4, 7]
#
# OUTPUT LISTS COMPLETE

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
## CONVERT RAW DATA TO DATAFRAME
# create a data frame from defined lists above.
weather_dictionary={
    "Weather City":weather_city,
    "Cloudiness":cloudiness,
    "Country":country,
    "Date":date,
    "Humidity":humidity,
    "Latitude":lat,
    "Longitude":lng,
    "Maximum Temperature":max_temp,
    "Wind Speed":wind_speed
}

#print(weather_dictionary)

# Data frame to store data setup
city_weather_df=pd.DataFrame(weather_dictionary)

# Save output dataframe data to csv file
city_weather_df.to_csv(output_data_file)

# Display dataframe
city_weather_df.head()
# Out:
#    Weather City  Cloudiness Country        Date  Humidity  Latitude  \
# 0  ponta do sol          24      PT  1587107062        78     38.73
# 1     mahajanga          20      MG  1587107062        48    -15.72
# 2      bien hoa          34      IT  1587107063        62     45.57
# 3  constitucion          28      CL  1587107063        62    -35.33
# 4         airai          25      TL  1587107063        68     -8.93
#
#    Longitude  Maximum Temperature  Wind Speed
# 0     -28.27                55.49        7.61
# 1      46.32                87.80       13.87
# 2       7.21                55.99        1.12
# 3     -72.42                56.64        5.91
# 4     125.41                69.08        3.58

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
