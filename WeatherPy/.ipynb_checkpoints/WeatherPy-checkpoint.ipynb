# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
## -------------------------
## HEADER COMMENTS
## Python-API-Challenge-WeatherPy-Homework
## Date Due April 18, 2020
## Author:  Rob Gauer

## FILE NAME: WeatherPy.ipynb  #Starter code with final version and is production code.
## VERSION: WeatherPy_robgauer_vfinal.ipynb  # Final code is a duplicate copy of 'WeatherPy.ipynb'
## -------------------------
# Read 'Preview README.md' for scope of work and instructions.

## DESCRIPTION
## -------------------------
# Part I - WeatherPy
# In this example, you'll be creating a Python script to visualize the weather of 500+ cities 
# across the world of varying distance from the equator. To accomplish this, you'll be utilizing
# a simple Python library, the OpenWeatherMap API, and a little common sense to create 
# a representative model of weather across world cities.

## QUESTION TO ASK
## -------------------------
## "What's the weather like as we approach the equator?"
## After each plot add a sentence or too explaining what the code is and analyzing.
## After each pair of plots explain what the linear regression is modeling such as 
## any relationships you notice and any other analysis you may have.
## -------------------------

## Your final notebook must:
## -------------------------
## Randomly select at least 500 unique (non-repeat) cities based on latitude and longitude.
## Perform a weather check on each of the cities using a series of successive API calls.
## Include a print log of each city as it's being processed with the city number and city name.
## Save a CSV of all retrieved data and a PNG image for each scatter plot.
## -------------------------
##
## Pearson's r" value:
## -------------------------
##   r <= 0.3 None or very weak
##   r 0.3 <= r < 0.5 Weak
##   r 0.5 <= r < 0.7 Moderate
##   r >= 0.7 strong
## -------------------------

## Analysis / Observations:  
## NOTES:  See individual charts that follow for details and Pearson's r-value assessment.
## -------------------------
# A. Temperature has a week correlation with latitude. As expected, the weather becomes warmer 
#       warmer as one approaches the equator (0 Deg. Latitude). 
# B. There is no strong relationship between latitude and humidity. 
#       however there is a slightly larger cluster of northern hemisphere cities with high humidity (above 60% humidity)
# C. There is no strong relationship between latitude and cloudiness. 
# D. There is no strong relationship between latitude and wind speed. Wind speed tends to generally
#       be betweeen 0 and 15 mph regardless of latitude
## -------------------------

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
import random

# Load API Keys...
from api_keys import weather_api_key
from api_keys import g_key
        
# Incorporated citipy to determine city based on latitude and longitude
# Remember to validate that via pip list that citipy module is installed
from citipy import citipy

print("-----------------------------------------------")
# Validate import of api_keys
print("INITIALIZATION TASKS...")
print("-----------------------------------------------")
print("Weather API key is:  "+ weather_api_key)
print("Google API key is:  "+ g_key)
print("API KEYS imported successfully...")

# Output Files (CSV)
output_data_file = "output_data/cities.csv"
output_data_file2 = "output_data/cities-cleaned.csv"
output_data_file3 = "output_data/cities-removed-humidity-over-100.csv"
output_city_log = "output_data/cities-output-write-log.csv"
#with open ('cities-output-write-log,"w") as out_file:
#   out_file.write("")

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Initialization and define URL to obtain data query end-points
units="imperial"
count_loop=0
loop_set=1
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={units}&q="
#query_url="http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units={units}"
print(query_url)
print("query_url loaded successfully...")
print("-----------------------------------------------")
# Out:
# -----------------------------------------------
# INITIALIZATION TASKS...
# -----------------------------------------------
# Weather API key is:  7353f39050ebd58b7f2079c24baa85f5
# Google API key is:  AIzaSyAtGIaEU0IXi5RuC9hmdjTftZhikNMFNiI
# API KEYS imported successfully...
# http://api.openweathermap.org/data/2.5/weather?appid=7353f39050ebd58b7f2079c24baa85f5&units=imperial&q=
# query_url loaded successfully...
# -----------------------------------------------

# %% [markdown]
# ## Generate Cities List

# %%
## GENERATE CITIES LIST
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
    
# Create a set of random lat and lng combinations
#lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
#lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lats = np.random.uniform(low=-90.000,high=90.000,size=1500)
lngs = np.random.uniform(low=-180.000,high=180.000,size=1500)
lat_lngs = zip(lats,lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city=citipy.nearest_city(lat_lng[0],lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))

# Weather dataframe formatting
city_format={"City":cities}

# Data frame to store data for cities
city_data_df=pd.DataFrame(city_format)
city_data_df
# Out:
# 645
#                     City
# 0          mar del plata
# 1             itupiranga
# 2             ordynskoye
# 3              taolanaro
# 4                ushuaia
# ..                   ...
# 640           quang ngai
# 641               iglino
# 642             gorodets
# 643  presidente epitacio
# 644        zelenoborskiy
#
# [645 rows x 1 columns]

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
## PERFORM API CALLS
# List for holding response values
weather_city=[]
cloudiness=[]
country=[]
date=[]
humidity=[]
lat=[]
lng=[]
max_temp=[]
wind_speed=[]

# Loop through cities by api calls to url and populate lists
for city in cities:
    try:
        print(f"Processing Record {count_loop} in Loop Set [{loop_set}|{city}")
        #with open ('cities-output-write-log,"a") as out_file:
        #    out_file.write(line)
        #response=requests.get(query_url+city).json()
        #weather_city.append(response['city'])
        response=requests.get(query_url+city.replace(" ","&")).json()
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
        if count_loop>49:
            count_loop=1
            loop_set+=1
            weather_city.append(city)
            # Add a (sixty-five second) interval between queries to stay within API query limits
            time.sleep(65)
        else:
            count_loop+=1
            weather_city.append(city)
    except:
        print("")
        print("EXCEPTION: City name is not found. Skip to next city...")
        print("")
print("")
print("------------------------------Retrieval Complete------------------------------")
print("")
print("OUTPUT LISTS")
print("")
print(f"Weather City List information is:  {weather_city}")
print("")
print(f"Cloudiness List information is:  {cloudiness}")
print("")
print(f"Country List information is:  {country}")
print("")
print(f"Date List information is:  {date}")
print("")
print(f"Humidities List information is:  {humidity}")
print("")
print(f"Latitude List information is:  {lat}")
print("")
print(f"Longitude List information is:  {lng}")
print("")
print(f"Maximum Temperature List information is:  {max_temp}")
print("")
print(f"Wind Speed List information is:  {wind_speed}")
print("")
print("OUTPUT LISTS COMPLETE")
# Out:
# Processing Record 0 in Loop Set [1|mar del plata
# Processing Record 1 in Loop Set [1|itupiranga
# Processing Record 2 in Loop Set [1|ordynskoye
# Processing Record 3 in Loop Set [1|taolanaro
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 3 in Loop Set [1|ushuaia
# Processing Record 4 in Loop Set [1|hobart
# Processing Record 5 in Loop Set [1|bluff
# Processing Record 6 in Loop Set [1|lagoa
# Processing Record 7 in Loop Set [1|nikolskoye
# Processing Record 8 in Loop Set [1|huarmey
# Processing Record 9 in Loop Set [1|longyearbyen
# Processing Record 10 in Loop Set [1|hami
# Processing Record 11 in Loop Set [1|solhan
# Processing Record 12 in Loop Set [1|tuktoyaktuk
# Processing Record 13 in Loop Set [1|bredasdorp
# Processing Record 14 in Loop Set [1|pavilosta
# Processing Record 15 in Loop Set [1|saldanha
# Processing Record 16 in Loop Set [1|vaini
# Processing Record 17 in Loop Set [1|baidyabati
# Processing Record 18 in Loop Set [1|kapaa
# Processing Record 19 in Loop Set [1|lima
# Processing Record 20 in Loop Set [1|georgetown
# Processing Record 21 in Loop Set [1|erenhot
# Processing Record 22 in Loop Set [1|khatanga
# Processing Record 23 in Loop Set [1|maceio
# Processing Record 24 in Loop Set [1|katsuura
# Processing Record 25 in Loop Set [1|esperance
# Processing Record 26 in Loop Set [1|mataura
# Processing Record 27 in Loop Set [1|torit
# Processing Record 28 in Loop Set [1|bengkulu
# Processing Record 29 in Loop Set [1|livingston
# Processing Record 30 in Loop Set [1|harper
# Processing Record 31 in Loop Set [1|albany
# Processing Record 32 in Loop Set [1|jamestown
# Processing Record 33 in Loop Set [1|murgab
# Processing Record 34 in Loop Set [1|baghdad
# Processing Record 35 in Loop Set [1|atuona
# Processing Record 36 in Loop Set [1|east london
# Processing Record 37 in Loop Set [1|ferry pass
# Processing Record 38 in Loop Set [1|busselton
# Processing Record 39 in Loop Set [1|teya
# Processing Record 40 in Loop Set [1|ust-kuyga
# Processing Record 41 in Loop Set [1|kahului
# Processing Record 42 in Loop Set [1|bytow
# Processing Record 43 in Loop Set [1|san vicente
# Processing Record 44 in Loop Set [1|trjavna
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 44 in Loop Set [1|high level
# Processing Record 45 in Loop Set [1|nguiu
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 45 in Loop Set [1|hithadhoo
# Processing Record 46 in Loop Set [1|tsihombe
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 46 in Loop Set [1|siimusti
# Processing Record 47 in Loop Set [1|port alfred
# Processing Record 48 in Loop Set [1|cape town
# Processing Record 49 in Loop Set [1|rikitea
# Processing Record 50 in Loop Set [1|reconquista
# Processing Record 1 in Loop Set [2|voznesenye
# Processing Record 2 in Loop Set [2|ilulissat
# Processing Record 3 in Loop Set [2|tiksi
# Processing Record 4 in Loop Set [2|apatou
# Processing Record 5 in Loop Set [2|tiznit
# Processing Record 6 in Loop Set [2|yellowknife
# Processing Record 7 in Loop Set [2|bambous virieux
# Processing Record 8 in Loop Set [2|punta arenas
# Processing Record 9 in Loop Set [2|ust-kamchatsk
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 9 in Loop Set [2|xixiang
# Processing Record 10 in Loop Set [2|hue
# Processing Record 11 in Loop Set [2|kokkola
# Processing Record 12 in Loop Set [2|wattegama
# Processing Record 13 in Loop Set [2|victoria
# Processing Record 14 in Loop Set [2|canberra
# Processing Record 15 in Loop Set [2|jawa
# Processing Record 16 in Loop Set [2|lluta
# Processing Record 17 in Loop Set [2|miri
# Processing Record 18 in Loop Set [2|grand gaube
# Processing Record 19 in Loop Set [2|cherskiy
# Processing Record 20 in Loop Set [2|sistranda
# Processing Record 21 in Loop Set [2|gat
# Processing Record 22 in Loop Set [2|qaanaaq
# Processing Record 23 in Loop Set [2|aksu
# Processing Record 24 in Loop Set [2|marshfield
# Processing Record 25 in Loop Set [2|aklavik
# Processing Record 26 in Loop Set [2|russell
# Processing Record 27 in Loop Set [2|pacsa
# Processing Record 28 in Loop Set [2|wuda
# Processing Record 29 in Loop Set [2|neuquen
# Processing Record 30 in Loop Set [2|groningen
# Processing Record 31 in Loop Set [2|hinganghat
# Processing Record 32 in Loop Set [2|pitimbu
# Processing Record 33 in Loop Set [2|saleilua
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 33 in Loop Set [2|marcona
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 33 in Loop Set [2|ketchikan
# Processing Record 34 in Loop Set [2|langres
# Processing Record 35 in Loop Set [2|barrow
# Processing Record 36 in Loop Set [2|butaritari
# Processing Record 37 in Loop Set [2|babushkin
# Processing Record 38 in Loop Set [2|calca
# Processing Record 39 in Loop Set [2|saskylakh
# Processing Record 40 in Loop Set [2|kushima
# Processing Record 41 in Loop Set [2|dikson
# Processing Record 42 in Loop Set [2|luderitz
# Processing Record 43 in Loop Set [2|luanda
# Processing Record 44 in Loop Set [2|hasaki
# Processing Record 45 in Loop Set [2|samusu
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 45 in Loop Set [2|pombia
# Processing Record 46 in Loop Set [2|haines junction
# Processing Record 47 in Loop Set [2|hambantota
# Processing Record 48 in Loop Set [2|batagay
# Processing Record 49 in Loop Set [2|juneau
# Processing Record 50 in Loop Set [2|arroyo
# Processing Record 1 in Loop Set [3|ribeira grande
# Processing Record 2 in Loop Set [3|chapais
# Processing Record 3 in Loop Set [3|kruisfontein
# Processing Record 4 in Loop Set [3|dondo
# Processing Record 5 in Loop Set [3|richards bay
# Processing Record 6 in Loop Set [3|rocha
# Processing Record 7 in Loop Set [3|maple creek
# Processing Record 8 in Loop Set [3|haibowan
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 8 in Loop Set [3|kiunga
# Processing Record 9 in Loop Set [3|carnarvon
# Processing Record 10 in Loop Set [3|jardim
# Processing Record 11 in Loop Set [3|lasa
# Processing Record 12 in Loop Set [3|puerto ayora
# Processing Record 13 in Loop Set [3|grand river south east
# Processing Record 14 in Loop Set [3|broome
# Processing Record 15 in Loop Set [3|trincomalee
# Processing Record 16 in Loop Set [3|lubao
# Processing Record 17 in Loop Set [3|barentsburg
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 17 in Loop Set [3|loandjili
# Processing Record 18 in Loop Set [3|arraial do cabo
# Processing Record 19 in Loop Set [3|hermanus
# Processing Record 20 in Loop Set [3|padampur
# Processing Record 21 in Loop Set [3|haapiti
# Processing Record 22 in Loop Set [3|ngunguru
# Processing Record 23 in Loop Set [3|tanout
# Processing Record 24 in Loop Set [3|kysyl-syr
# Processing Record 25 in Loop Set [3|svetlyy
# Processing Record 26 in Loop Set [3|zavyalovo
# Processing Record 27 in Loop Set [3|deputatskiy
# Processing Record 28 in Loop Set [3|ruatoria
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 28 in Loop Set [3|santa maria
# Processing Record 29 in Loop Set [3|tasiilaq
# Processing Record 30 in Loop Set [3|antofagasta
# Processing Record 31 in Loop Set [3|mys shmidta
# Processing Record 32 in Loop Set [3|port elizabeth
# Processing Record 33 in Loop Set [3|vardo
# Processing Record 34 in Loop Set [3|castro
# Processing Record 35 in Loop Set [3|tessalit
# Processing Record 36 in Loop Set [3|saint-philippe
# Processing Record 37 in Loop Set [3|amderma
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 37 in Loop Set [3|skibbereen
# Processing Record 38 in Loop Set [3|kibala
# Processing Record 39 in Loop Set [3|atbasar
# Processing Record 40 in Loop Set [3|avarua
# Processing Record 41 in Loop Set [3|gizo
# Processing Record 42 in Loop Set [3|petatlan
# Processing Record 43 in Loop Set [3|obihiro
# Processing Record 44 in Loop Set [3|ouallam
# Processing Record 45 in Loop Set [3|lompoc
# Processing Record 46 in Loop Set [3|tiarei
# Processing Record 47 in Loop Set [3|impfondo
# Processing Record 48 in Loop Set [3|mayumba
# Processing Record 49 in Loop Set [3|namatanai
# Processing Record 50 in Loop Set [3|spearfish
# Processing Record 1 in Loop Set [4|new norfolk
# Processing Record 2 in Loop Set [4|alta floresta
# Processing Record 3 in Loop Set [4|gracias
# Processing Record 4 in Loop Set [4|pangnirtung
# Processing Record 5 in Loop Set [4|umm durman
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 5 in Loop Set [4|mahebourg
# Processing Record 6 in Loop Set [4|ambilobe
# Processing Record 7 in Loop Set [4|botwood
# Processing Record 8 in Loop Set [4|fortuna
# Processing Record 9 in Loop Set [4|ginir
# Processing Record 10 in Loop Set [4|geraldton
# Processing Record 11 in Loop Set [4|walvis bay
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 11 in Loop Set [4|upernavik
# Processing Record 12 in Loop Set [4|chibombo
# Processing Record 13 in Loop Set [4|kaputa
# Processing Record 14 in Loop Set [4|madaoua
# Processing Record 15 in Loop Set [4|honiara
# Processing Record 16 in Loop Set [4|sembe
# Processing Record 17 in Loop Set [4|santa isabel
# Processing Record 18 in Loop Set [4|do gonbadan
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 18 in Loop Set [4|joigny
# Processing Record 19 in Loop Set [4|barra dos coqueiros
# Processing Record 20 in Loop Set [4|vestmannaeyjar
# Processing Record 21 in Loop Set [4|nizhneyansk
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 21 in Loop Set [4|port hardy
# Processing Record 22 in Loop Set [4|komsomolskiy
# Processing Record 23 in Loop Set [4|bethel
# Processing Record 24 in Loop Set [4|bathsheba
# Processing Record 25 in Loop Set [4|kalachinsk
# Processing Record 26 in Loop Set [4|chokurdakh
# Processing Record 27 in Loop Set [4|san patricio
# Processing Record 28 in Loop Set [4|lebu
# Processing Record 29 in Loop Set [4|okhotsk
# Processing Record 30 in Loop Set [4|flagstaff
# Processing Record 31 in Loop Set [4|olavarria
# Processing Record 32 in Loop Set [4|nowe miasto lubawskie
# Processing Record 33 in Loop Set [4|alofi
# Processing Record 34 in Loop Set [4|nhulunbuy
# Processing Record 35 in Loop Set [4|dorado
# Processing Record 36 in Loop Set [4|saint george
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 36 in Loop Set [4|marrakesh
# Processing Record 37 in Loop Set [4|chicama
# Processing Record 38 in Loop Set [4|pandavapura
# Processing Record 39 in Loop Set [4|samalaeulu
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 39 in Loop Set [4|vila franca do campo
# Processing Record 40 in Loop Set [4|bonoua
# Processing Record 41 in Loop Set [4|keti bandar
# Processing Record 42 in Loop Set [4|colares
# Processing Record 43 in Loop Set [4|ancud
# Processing Record 44 in Loop Set [4|goundam
# Processing Record 45 in Loop Set [4|bonavista
# Processing Record 46 in Loop Set [4|klaksvik
# Processing Record 47 in Loop Set [4|turukhansk
# Processing Record 48 in Loop Set [4|parintins
# Processing Record 49 in Loop Set [4|parainen
# Processing Record 50 in Loop Set [4|saint-pierre
# Processing Record 1 in Loop Set [5|vanimo
# Processing Record 2 in Loop Set [5|kununurra
# Processing Record 3 in Loop Set [5|torbay
# Processing Record 4 in Loop Set [5|panguna
# Processing Record 5 in Loop Set [5|ocean city
# Processing Record 6 in Loop Set [5|vaitupu
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 6 in Loop Set [5|mugumu
# Processing Record 7 in Loop Set [5|hilo
# Processing Record 8 in Loop Set [5|tutoia
# Processing Record 9 in Loop Set [5|pedasi
# Processing Record 10 in Loop Set [5|cervo
# Processing Record 11 in Loop Set [5|narsaq
# Processing Record 12 in Loop Set [5|husavik
# Processing Record 13 in Loop Set [5|zalantun
# Processing Record 14 in Loop Set [5|sept-iles
# Processing Record 15 in Loop Set [5|gorno-chuyskiy
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 15 in Loop Set [5|inta
# Processing Record 16 in Loop Set [5|ochakiv
# Processing Record 17 in Loop Set [5|hamilton
# Processing Record 18 in Loop Set [5|boende
# Processing Record 19 in Loop Set [5|kiama
# Processing Record 20 in Loop Set [5|moju
# Processing Record 21 in Loop Set [5|thompson
# Processing Record 22 in Loop Set [5|caravelas
# Processing Record 23 in Loop Set [5|vilhena
# Processing Record 24 in Loop Set [5|concordia
# Processing Record 25 in Loop Set [5|yulara
# Processing Record 26 in Loop Set [5|nogliki
# Processing Record 27 in Loop Set [5|port moresby
# Processing Record 28 in Loop Set [5|taksimo
# Processing Record 29 in Loop Set [5|college
# Processing Record 30 in Loop Set [5|mount gambier
# Processing Record 31 in Loop Set [5|ghanzi
# Processing Record 32 in Loop Set [5|lakatoro
# Processing Record 33 in Loop Set [5|los llanos de aridane
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 33 in Loop Set [5|samdari
# Processing Record 34 in Loop Set [5|kaduna
# Processing Record 35 in Loop Set [5|tecoanapa
# Processing Record 36 in Loop Set [5|nanortalik
# Processing Record 37 in Loop Set [5|cidreira
# Processing Record 38 in Loop Set [5|horsham
# Processing Record 39 in Loop Set [5|black river
# Processing Record 40 in Loop Set [5|kalaleh
# Processing Record 41 in Loop Set [5|clyde river
# Processing Record 42 in Loop Set [5|lavrentiya
# Processing Record 43 in Loop Set [5|pavagada
# Processing Record 44 in Loop Set [5|marietta
# Processing Record 45 in Loop Set [5|berberati
# Processing Record 46 in Loop Set [5|karratha
# Processing Record 47 in Loop Set [5|faanui
# Processing Record 48 in Loop Set [5|san cristobal
# Processing Record 49 in Loop Set [5|vicuna
# Processing Record 50 in Loop Set [5|constitucion
# Processing Record 1 in Loop Set [6|issoudun
# Processing Record 2 in Loop Set [6|carnot
# Processing Record 3 in Loop Set [6|coquimbo
# Processing Record 4 in Loop Set [6|saleaula
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 4 in Loop Set [6|illoqqortoormiut
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 4 in Loop Set [6|mahibadhoo
# Processing Record 5 in Loop Set [6|sentyabrskiy
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 5 in Loop Set [6|gladstone
# Processing Record 6 in Loop Set [6|porto novo
# Processing Record 7 in Loop Set [6|bargal
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 7 in Loop Set [6|tuatapere
# Processing Record 8 in Loop Set [6|banff
# Processing Record 9 in Loop Set [6|santa marta
# Processing Record 10 in Loop Set [6|sioux lookout
# Processing Record 11 in Loop Set [6|bukama
# Processing Record 12 in Loop Set [6|souris
# Processing Record 13 in Loop Set [6|cockburn town
# Processing Record 14 in Loop Set [6|namibe
# Processing Record 15 in Loop Set [6|mount isa
# Processing Record 16 in Loop Set [6|leningradskiy
# Processing Record 17 in Loop Set [6|kavieng
# Processing Record 18 in Loop Set [6|rudnya
# Processing Record 19 in Loop Set [6|veraval
# Processing Record 20 in Loop Set [6|raudeberg
# Processing Record 21 in Loop Set [6|nemuro
# Processing Record 22 in Loop Set [6|siparia
# Processing Record 23 in Loop Set [6|souillac
# Processing Record 24 in Loop Set [6|westport
# Processing Record 25 in Loop Set [6|auch
# Processing Record 26 in Loop Set [6|cayenne
# Processing Record 27 in Loop Set [6|touros
# Processing Record 28 in Loop Set [6|novoorsk
# Processing Record 29 in Loop Set [6|bowen
# Processing Record 30 in Loop Set [6|bridlington
# Processing Record 31 in Loop Set [6|paamiut
# Processing Record 32 in Loop Set [6|meulaboh
# Processing Record 33 in Loop Set [6|rungata
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 33 in Loop Set [6|sidi bu zayd
# Processing Record 34 in Loop Set [6|natal
# Processing Record 35 in Loop Set [6|guozhen
# Processing Record 36 in Loop Set [6|ponta do sol
# Processing Record 37 in Loop Set [6|zeewolde
# Processing Record 38 in Loop Set [6|svetlogorsk
# Processing Record 39 in Loop Set [6|strelka
# Processing Record 40 in Loop Set [6|old town
# Processing Record 41 in Loop Set [6|burica
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 41 in Loop Set [6|chuy
# Processing Record 42 in Loop Set [6|ulaangom
# Processing Record 43 in Loop Set [6|da nang
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 43 in Loop Set [6|atar
# Processing Record 44 in Loop Set [6|dhidhdhoo
# Processing Record 45 in Loop Set [6|sorland
# Processing Record 46 in Loop Set [6|hirara
# Processing Record 47 in Loop Set [6|saint-joseph
# Processing Record 48 in Loop Set [6|utiroa
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 48 in Loop Set [6|todos santos
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 48 in Loop Set [6|hutchinson
# Processing Record 49 in Loop Set [6|portland
# Processing Record 50 in Loop Set [6|trairi
# Processing Record 1 in Loop Set [7|port hawkesbury
# Processing Record 2 in Loop Set [7|vierzon
# Processing Record 3 in Loop Set [7|amurzet
# Processing Record 4 in Loop Set [7|koppal
# Processing Record 5 in Loop Set [7|dalbandin
# Processing Record 6 in Loop Set [7|porto santo
# Processing Record 7 in Loop Set [7|banjarmasin
# Processing Record 8 in Loop Set [7|kirakira
# Processing Record 9 in Loop Set [7|la union
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 9 in Loop Set [7|temaraia
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 9 in Loop Set [7|mastic
# Processing Record 10 in Loop Set [7|belmonte
# Processing Record 11 in Loop Set [7|sumkino
# Processing Record 12 in Loop Set [7|quatre cocos
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 12 in Loop Set [7|santa cruz
# Processing Record 13 in Loop Set [7|qandala
# Processing Record 14 in Loop Set [7|krasnoborsk
# Processing Record 15 in Loop Set [7|sao filipe
# Processing Record 16 in Loop Set [7|moranbah
# Processing Record 17 in Loop Set [7|erdenet
# Processing Record 18 in Loop Set [7|belushya guba
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 18 in Loop Set [7|vernon
# Processing Record 19 in Loop Set [7|micomeseng
# Processing Record 20 in Loop Set [7|attawapiskat
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 20 in Loop Set [7|el faiyum
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 20 in Loop Set [7|santa clara
# Processing Record 21 in Loop Set [7|uberlandia
# Processing Record 22 in Loop Set [7|emerald
# Processing Record 23 in Loop Set [7|great falls
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 23 in Loop Set [7|owando
# Processing Record 24 in Loop Set [7|millerovo
# Processing Record 25 in Loop Set [7|barinas
# Processing Record 26 in Loop Set [7|victor harbor
# Processing Record 27 in Loop Set [7|victoria point
# Processing Record 28 in Loop Set [7|waiouru
# Processing Record 29 in Loop Set [7|fairbanks
# Processing Record 30 in Loop Set [7|pacific grove
# Processing Record 31 in Loop Set [7|khandwa
# Processing Record 32 in Loop Set [7|jos
# Processing Record 33 in Loop Set [7|conceicao do araguaia
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 33 in Loop Set [7|provideniya
# Processing Record 34 in Loop Set [7|dire
# Processing Record 35 in Loop Set [7|bakchar
# Processing Record 36 in Loop Set [7|arkhara
# Processing Record 37 in Loop Set [7|baruun-urt
# Processing Record 38 in Loop Set [7|kavali
# Processing Record 39 in Loop Set [7|bardiyah
# Processing Record 40 in Loop Set [7|barentu
# Processing Record 41 in Loop Set [7|moerai
# Processing Record 42 in Loop Set [7|puerto madryn
# Processing Record 43 in Loop Set [7|hervey bay
# Processing Record 44 in Loop Set [7|makungu
# Processing Record 45 in Loop Set [7|airai
# Processing Record 46 in Loop Set [7|moulmeingyun
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 46 in Loop Set [7|labuhan
# Processing Record 47 in Loop Set [7|sohbatpur
# Processing Record 48 in Loop Set [7|verkhnevilyuysk
# Processing Record 49 in Loop Set [7|coro
# Processing Record 50 in Loop Set [7|bairiki
# Processing Record 1 in Loop Set [8|tolmachevo
# Processing Record 2 in Loop Set [8|cabo san lucas
# Processing Record 3 in Loop Set [8|show low
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 3 in Loop Set [8|sibolga
# Processing Record 4 in Loop Set [8|pontal do parana
# Processing Record 5 in Loop Set [8|huicungo
# Processing Record 6 in Loop Set [8|petropavlovsk-kamchatskiy
# Processing Record 7 in Loop Set [8|port macquarie
# Processing Record 8 in Loop Set [8|severnoye
# Processing Record 9 in Loop Set [8|kamenskoye
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 9 in Loop Set [8|salvador
# Processing Record 10 in Loop Set [8|burnie
# Processing Record 11 in Loop Set [8|san buenaventura
# Processing Record 12 in Loop Set [8|puerto escondido
# Processing Record 13 in Loop Set [8|marzuq
# Processing Record 14 in Loop Set [8|berlevag
# Processing Record 15 in Loop Set [8|nata
# Processing Record 16 in Loop Set [8|norman wells
# Processing Record 17 in Loop Set [8|salinopolis
# Processing Record 18 in Loop Set [8|sabang
# Processing Record 19 in Loop Set [8|san fernando
# Processing Record 20 in Loop Set [8|shaoguan
# Processing Record 21 in Loop Set [8|dovers
# Processing Record 22 in Loop Set [8|saint-georges
# Processing Record 23 in Loop Set [8|boromo
# Processing Record 24 in Loop Set [8|port-gentil
# Processing Record 25 in Loop Set [8|talnakh
# Processing Record 26 in Loop Set [8|mehamn
# Processing Record 27 in Loop Set [8|nancha
# Processing Record 28 in Loop Set [8|nago
# Processing Record 29 in Loop Set [8|san jose
# Processing Record 30 in Loop Set [8|gamba
# Processing Record 31 in Loop Set [8|nieuw amsterdam
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 31 in Loop Set [8|nantucket
# Processing Record 32 in Loop Set [8|liverpool
# Processing Record 33 in Loop Set [8|itaituba
# Processing Record 34 in Loop Set [8|nagua
# Processing Record 35 in Loop Set [8|moose factory
# Processing Record 36 in Loop Set [8|gesztely
# Processing Record 37 in Loop Set [8|kodiak
# Processing Record 38 in Loop Set [8|kalach-na-donu
# Processing Record 39 in Loop Set [8|knysna
# Processing Record 40 in Loop Set [8|griffith
# Processing Record 41 in Loop Set [8|iralaya
# Processing Record 42 in Loop Set [8|naze
# Processing Record 43 in Loop Set [8|wladyslawowo
# Processing Record 44 in Loop Set [8|manadhoo
# Processing Record 45 in Loop Set [8|havre
# Processing Record 46 in Loop Set [8|pasighat
# Processing Record 47 in Loop Set [8|eureka
# Processing Record 48 in Loop Set [8|lata
# Processing Record 49 in Loop Set [8|suluq
# Processing Record 50 in Loop Set [8|evanston
# Processing Record 1 in Loop Set [9|tavda
# Processing Record 2 in Loop Set [9|thinadhoo
# Processing Record 3 in Loop Set [9|salina
# Processing Record 4 in Loop Set [9|bayevo
# Processing Record 5 in Loop Set [9|sao miguel do araguaia
# Processing Record 6 in Loop Set [9|bereda
# Processing Record 7 in Loop Set [9|havre-saint-pierre
# Processing Record 8 in Loop Set [9|kieta
# Processing Record 9 in Loop Set [9|morgan city
# Processing Record 10 in Loop Set [9|kidal
# Processing Record 11 in Loop Set [9|myitkyina
# Processing Record 12 in Loop Set [9|nizhniy kuranakh
# Processing Record 13 in Loop Set [9|les cayes
# Processing Record 14 in Loop Set [9|mombetsu
# Processing Record 15 in Loop Set [9|isangel
# Processing Record 16 in Loop Set [9|sao joao da barra
# Processing Record 17 in Loop Set [9|grande-riviere
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 17 in Loop Set [9|maku
# Processing Record 18 in Loop Set [9|baker city
# Processing Record 19 in Loop Set [9|kralendijk
# Processing Record 20 in Loop Set [9|zaozhuang
# Processing Record 21 in Loop Set [9|shellbrook
# Processing Record 22 in Loop Set [9|sorvag
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 22 in Loop Set [9|krasnoselkup
# Processing Record 23 in Loop Set [9|sengiley
# Processing Record 24 in Loop Set [9|hofn
# Processing Record 25 in Loop Set [9|rockland
# Processing Record 26 in Loop Set [9|north bend
# Processing Record 27 in Loop Set [9|poum
# Processing Record 28 in Loop Set [9|ambon
# Processing Record 29 in Loop Set [9|general roca
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 29 in Loop Set [9|mangaratiba
# Processing Record 30 in Loop Set [9|abu kamal
# Processing Record 31 in Loop Set [9|la ronge
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 31 in Loop Set [9|tibu
# Processing Record 32 in Loop Set [9|murray bridge
# Processing Record 33 in Loop Set [9|novikovo
# Processing Record 34 in Loop Set [9|yamada
# Processing Record 35 in Loop Set [9|lashio
# Processing Record 36 in Loop Set [9|muisne
# Processing Record 37 in Loop Set [9|pevek
# Processing Record 38 in Loop Set [9|weligama
# Processing Record 39 in Loop Set [9|taoudenni
# Processing Record 40 in Loop Set [9|laguna
# Processing Record 41 in Loop Set [9|portobelo
# Processing Record 42 in Loop Set [9|semnan
# Processing Record 43 in Loop Set [9|pandan
# Processing Record 44 in Loop Set [9|izhma
# Processing Record 45 in Loop Set [9|nioro
# Processing Record 46 in Loop Set [9|kaitangata
# Processing Record 47 in Loop Set [9|djambala
# Processing Record 48 in Loop Set [9|turayf
# Processing Record 49 in Loop Set [9|mayo
# Processing Record 50 in Loop Set [9|aleysk
# Processing Record 1 in Loop Set [10|el juncal
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 1 in Loop Set [10|chauk
# Processing Record 2 in Loop Set [10|cobadin
# Processing Record 3 in Loop Set [10|nautla
# Processing Record 4 in Loop Set [10|sivas
# Processing Record 5 in Loop Set [10|batemans bay
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 5 in Loop Set [10|anchorage
# Processing Record 6 in Loop Set [10|sambava
# Processing Record 7 in Loop Set [10|san pedro
# Processing Record 8 in Loop Set [10|miandrivazo
# Processing Record 9 in Loop Set [10|poya
# Processing Record 10 in Loop Set [10|gornyy
# Processing Record 11 in Loop Set [10|coihaique
# Processing Record 12 in Loop Set [10|fort saint john
# Processing Record 13 in Loop Set [10|qasigiannguit
# Processing Record 14 in Loop Set [10|olafsvik
# Processing Record 15 in Loop Set [10|pemangkat
# Processing Record 16 in Loop Set [10|pisco
# Processing Record 17 in Loop Set [10|bushehr
# Processing Record 18 in Loop Set [10|dillon
# Processing Record 19 in Loop Set [10|alugan
# Processing Record 20 in Loop Set [10|camacha
# Processing Record 21 in Loop Set [10|mapiripan
# Processing Record 22 in Loop Set [10|akureyri
# Processing Record 23 in Loop Set [10|nome
# Processing Record 24 in Loop Set [10|sumenep
# Processing Record 25 in Loop Set [10|yaan
# Processing Record 26 in Loop Set [10|san andres
# Processing Record 27 in Loop Set [10|san-pedro
# Processing Record 28 in Loop Set [10|paucartambo
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 28 in Loop Set [10|shakawe
# Processing Record 29 in Loop Set [10|borogontsy
# Processing Record 30 in Loop Set [10|saquena
# Processing Record 31 in Loop Set [10|kutum
# Processing Record 32 in Loop Set [10|elat
# Processing Record 33 in Loop Set [10|minna
# Processing Record 34 in Loop Set [10|north platte
# Processing Record 35 in Loop Set [10|dauriya
# Processing Record 36 in Loop Set [10|zhezkazgan
# Processing Record 37 in Loop Set [10|seoul
# Processing Record 38 in Loop Set [10|vyazemskiy
# Processing Record 39 in Loop Set [10|lulea
# Processing Record 40 in Loop Set [10|egvekinot
# Processing Record 41 in Loop Set [10|brewster
# Processing Record 42 in Loop Set [10|sinop
# Processing Record 43 in Loop Set [10|ahipara
# Processing Record 44 in Loop Set [10|saugus
# Processing Record 45 in Loop Set [10|vad
# Processing Record 46 in Loop Set [10|dunedin
# Processing Record 47 in Loop Set [10|goderich
# Processing Record 48 in Loop Set [10|arman
# Processing Record 49 in Loop Set [10|codrington
# Processing Record 50 in Loop Set [10|merauke
# Processing Record 1 in Loop Set [11|tateyama
# Processing Record 2 in Loop Set [11|ostrovnoy
# Processing Record 3 in Loop Set [11|alice springs
# Processing Record 4 in Loop Set [11|kenai
# Processing Record 5 in Loop Set [11|hegang
# Processing Record 6 in Loop Set [11|diffa
# Processing Record 7 in Loop Set [11|parakou
# Processing Record 8 in Loop Set [11|aksarka
# Processing Record 9 in Loop Set [11|kenora
# Processing Record 10 in Loop Set [11|saint-francois
# Processing Record 11 in Loop Set [11|faya
# Processing Record 12 in Loop Set [11|asau
# Processing Record 13 in Loop Set [11|pedernales
# Processing Record 14 in Loop Set [11|betanzos
# Processing Record 15 in Loop Set [11|port keats
# Processing Record 16 in Loop Set [11|sydney
# Processing Record 17 in Loop Set [11|cumberland
# Processing Record 18 in Loop Set [11|krasnogorskoye
# Processing Record 19 in Loop Set [11|sur
# Processing Record 20 in Loop Set [11|atherton
# Processing Record 21 in Loop Set [11|piacabucu
# Processing Record 22 in Loop Set [11|kavaratti
# Processing Record 23 in Loop Set [11|heide
# Processing Record 24 in Loop Set [11|totton
# Processing Record 25 in Loop Set [11|gela
# Processing Record 26 in Loop Set [11|skalistyy
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 26 in Loop Set [11|valparaiso
# Processing Record 27 in Loop Set [11|saurimo
# Processing Record 28 in Loop Set [11|sitka
# Processing Record 29 in Loop Set [11|ust-tsilma
# Processing Record 30 in Loop Set [11|ekimchan
# Processing Record 31 in Loop Set [11|boa vista
# Processing Record 32 in Loop Set [11|hualmay
# Processing Record 33 in Loop Set [11|loukhi
# Processing Record 34 in Loop Set [11|gambiran
# Processing Record 35 in Loop Set [11|beloha
# Processing Record 36 in Loop Set [11|tilichiki
# Processing Record 37 in Loop Set [11|khonuu
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 37 in Loop Set [11|atambua
# Processing Record 38 in Loop Set [11|barbar
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 38 in Loop Set [11|mao
# Processing Record 39 in Loop Set [11|severo-kurilsk
# Processing Record 40 in Loop Set [11|ponta delgada
# Processing Record 41 in Loop Set [11|vostok
# Processing Record 42 in Loop Set [11|tanggul
# Processing Record 43 in Loop Set [11|serenje
# Processing Record 44 in Loop Set [11|meaux
# Processing Record 45 in Loop Set [11|champaign
# Processing Record 46 in Loop Set [11|banda aceh
# Processing Record 47 in Loop Set [11|mahajanga
# Processing Record 48 in Loop Set [11|srednekolymsk
# Processing Record 49 in Loop Set [11|te anau
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 49 in Loop Set [11|dawlatabad
# Processing Record 50 in Loop Set [11|hansot
# Processing Record 1 in Loop Set [12|wisconsin rapids
# Processing Record 2 in Loop Set [12|mongoumba
# Processing Record 3 in Loop Set [12|sarkand
# Processing Record 4 in Loop Set [12|kendari
# Processing Record 5 in Loop Set [12|bojnurd
# Processing Record 6 in Loop Set [12|manali
# Processing Record 7 in Loop Set [12|san policarpo
# Processing Record 8 in Loop Set [12|hvide sande
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 8 in Loop Set [12|bar harbor
# Processing Record 9 in Loop Set [12|asosa
# Processing Record 10 in Loop Set [12|patacamaya
# Processing Record 11 in Loop Set [12|arvi
# Processing Record 12 in Loop Set [12|umm lajj
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 12 in Loop Set [12|perth
# Processing Record 13 in Loop Set [12|kirtipur
# Processing Record 14 in Loop Set [12|zheleznogorsk
# Processing Record 15 in Loop Set [12|rantepao
# Processing Record 16 in Loop Set [12|aloja
# Processing Record 17 in Loop Set [12|rio gallegos
# Processing Record 18 in Loop Set [12|aksehir
# Processing Record 19 in Loop Set [12|roald
# Processing Record 20 in Loop Set [12|novyy urengoy
# Processing Record 21 in Loop Set [12|waingapu
# Processing Record 22 in Loop Set [12|riyadh
# Processing Record 23 in Loop Set [12|bud
# Processing Record 24 in Loop Set [12|williamsburg
# Processing Record 25 in Loop Set [12|dolbeau
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 25 in Loop Set [12|kismayo
# Processing Record 26 in Loop Set [12|corpus christi
# Processing Record 27 in Loop Set [12|saint-leu
# Processing Record 28 in Loop Set [12|bograd
# Processing Record 29 in Loop Set [12|daru
# Processing Record 30 in Loop Set [12|ranikhet
# Processing Record 31 in Loop Set [12|bubaque
# Processing Record 32 in Loop Set [12|salalah
# Processing Record 33 in Loop Set [12|banikoara
# Processing Record 34 in Loop Set [12|quang ngai
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 34 in Loop Set [12|iglino
# Processing Record 35 in Loop Set [12|gorodets
# Processing Record 36 in Loop Set [12|presidente epitacio
# Processing Record 37 in Loop Set [12|zelenoborskiy
#
# ------------------------------Retrieval Complete------------------------------
#
# OUTPUT LISTS
#
# Weather City List information is:  ['mar del plata', 'itupiranga', 'ordynskoye', 'ushuaia', 'hobart', 'bluff', 'lagoa', 'nikolskoye', 'huarmey', 'longyearbyen', 'hami', 'solhan', 'tuktoyaktuk', 'bredasdorp', 'pavilosta', 'saldanha', 'vaini', 'baidyabati', 'kapaa', 'lima', 'georgetown', 'erenhot', 'khatanga', 'maceio', 'katsuura', 'esperance', 'mataura', 'torit', 'bengkulu', 'livingston', 'harper', 'albany', 'jamestown', 'murgab', 'baghdad', 'atuona', 'east london', 'ferry pass', 'busselton', 'teya', 'ust-kuyga', 'kahului', 'bytow', 'san vicente', 'high level', 'hithadhoo', 'siimusti', 'port alfred', 'cape town', 'rikitea', 'reconquista', 'voznesenye', 'ilulissat', 'tiksi', 'apatou', 'tiznit', 'yellowknife', 'bambous virieux', 'punta arenas', 'xixiang', 'hue', 'kokkola', 'wattegama', 'victoria', 'canberra', 'jawa', 'lluta', 'miri', 'grand gaube', 'cherskiy', 'sistranda', 'gat', 'qaanaaq', 'aksu', 'marshfield', 'aklavik', 'russell', 'pacsa', 'wuda', 'neuquen', 'groningen', 'hinganghat', 'pitimbu', 'ketchikan', 'langres', 'barrow', 'butaritari', 'babushkin', 'calca', 'saskylakh', 'kushima', 'dikson', 'luderitz', 'luanda', 'hasaki', 'pombia', 'haines junction', 'hambantota', 'batagay', 'juneau', 'arroyo', 'ribeira grande', 'chapais', 'kruisfontein', 'dondo', 'richards bay', 'rocha', 'maple creek', 'kiunga', 'carnarvon', 'jardim', 'lasa', 'puerto ayora', 'grand river south east', 'broome', 'trincomalee', 'lubao', 'loandjili', 'arraial do cabo', 'hermanus', 'padampur', 'haapiti', 'ngunguru', 'tanout', 'kysyl-syr', 'svetlyy', 'zavyalovo', 'deputatskiy', 'santa maria', 'tasiilaq', 'antofagasta', 'mys shmidta', 'port elizabeth', 'vardo', 'castro', 'tessalit', 'saint-philippe', 'skibbereen', 'kibala', 'atbasar', 'avarua', 'gizo', 'petatlan', 'obihiro', 'ouallam', 'lompoc', 'tiarei', 'impfondo', 'mayumba', 'namatanai', 'spearfish', 'new norfolk', 'alta floresta', 'gracias', 'pangnirtung', 'mahebourg', 'ambilobe', 'botwood', 'fortuna', 'ginir', 'geraldton', 'upernavik', 'chibombo', 'kaputa', 'madaoua', 'honiara', 'sembe', 'santa isabel', 'joigny', 'barra dos coqueiros', 'vestmannaeyjar', 'port hardy', 'komsomolskiy', 'bethel', 'bathsheba', 'kalachinsk', 'chokurdakh', 'san patricio', 'lebu
3.36, 6.93, 6.93, 4.29, 1.12, 3.42, 9.17, 11.41, 3.51, 8.14, 1.99, 7.7, 6.67, 10.29, 6.31, 3.36, 13.87, 2.13, 4.7, 2.04, 4.5, 3.53, 7.43, 5.37, 3.62, 12.28, 10.83, 1.36, 3.36, 13.94, 14.83, 4.83, 2.1, 8.1, 6.93, 20.8, 7.99, 6.93, 11.12, 1.19, 9.44, 20.8, 3.58, 3.83, 2.19, 4.7, 8.93, 8.41, 4.88, 2.66, 5.97, 2.51, 20.8, 4.7, 7.14, 0.67, 3, 2.01, 2.42, 10.29, 2.24, 5.3, 4.7, 9.17, 4.7, 7.11, 5.91, 19.46, 6.71, 7.81, 4.63, 18.34, 4.7, 12.12, 8.95, 6.71, 13.44, 5.99]
#
# OUTPUT LISTS COMPLETE

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
## CONVERT RAW DATA TO DATAFRAME
# create a data frame from defined lists above.
weather_dictionary={
    "Weather City":weather_city,
    "Cloudiness":cloudiness,
    "Country":country,
    "Date":date,
    "Humidity":humidity,
    "Latitude":lat,
    "Longitude":lng,
    "Maximum Temperature":max_temp,
    "Wind Speed":wind_speed
}

#print(weather_dictionary)

# Data frame to store data setup
city_weather_df=pd.DataFrame(weather_dictionary)

# Save output dataframe data to csv file
city_weather_df.to_csv(output_data_file)

# Display dataframe
city_weather_df.head()
# Out:
#     Weather City  Cloudiness Country        Date  Humidity  Latitude  \
# 0  mar del plata          90      ES  1587250522        93     43.40
# 1     itupiranga          20      BR  1587250443        94     -5.13
# 2     ordynskoye           0      RU  1587250522        76     54.37
# 3        ushuaia          40      AR  1587250522        57    -54.80
# 4         hobart          75      AU  1587250522        81    -42.88
#
#    Longitude  Maximum Temperature  Wind Speed
# 0      -4.01                59.00        5.82
# 1     -49.33                78.80        1.03
# 2      81.90                38.34        5.46
# 3     -68.30                48.20        3.91
# 4     147.33                48.99        8.05

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Create new datafrome for the identification and removal humidity values >=100%
toclean_city_weather_df=city_weather_df

# Identify cities with >= 100% humidity from within the dataframe
humidity_over100_df=toclean_city_weather_df.loc[(toclean_city_weather_df['Humidity']>=100)]
humidity_over100_df
                           
# Determine quantity of cities with >= 100% humidity levels
humidity_over100_df.count()
# Out:
# Weather City           16
# Cloudiness             16
# Country                16
# Date                   16
# Humidity               16
# Latitude               16
# Longitude              16
# Maximum Temperature    16
# Wind Speed             16
# dtype: int64

# %%
# Extract the records based on the index values to remove - review list
# Display the records with >= 100% humidity
humidity_over100_df
# Out:
#               Weather City  Cloudiness Country        Date  Humidity  \
# 67                    miri          75      MY  1587250425       100
# 84                 langres          41      FR  1587250597       100
# 92                luderitz           4      NA  1587250598       100
# 100                 arroyo          96      ES  1587250599       100
# 101         ribeira grande          40      ES  1587250664       100
# 137             skibbereen          90      IE  1587250669       100
# 182  nowe miasto lubawskie           0      PL  1587250740       100
# 210                  cervo          95      ES  1587250809       100
# 238                horsham          44      GB  1587250812       100
# 278               novoorsk          75      RU  1587250883       100
# 307            banjarmasin         100      ID  1587250952       100
# 329              fairbanks          90      US  1587250452       100
# 406                 bereda          76      ES  1587251095       100
# 436                 muisne          75      EC  1587251099       100
# 473                   nome          90      US  1587250502       100
# 514               betanzos          89      ES  1587251239       100
#
#      Latitude  Longitude  Maximum Temperature  Wind Speed
# 67       4.41     114.01                75.20        3.87
# 84      47.83       5.33                57.20        4.70
# 92     -26.65      15.16                57.20        5.82
# 100     41.61      -4.80                53.01        2.24
# 101     42.75      -8.44                50.00        1.14
# 137     51.55      -9.27                46.40       12.75
# 182     53.65      18.73                33.01        6.15
# 210     43.67      -7.41                48.99        2.93
# 238     51.06      -0.33                46.00        5.82
# 278     51.38      58.98                39.20       11.18
# 307     -3.32     114.59                77.00        3.36
# 329     64.84    -147.72                43.00        3.36
# 406     43.27      -7.54                48.99        0.25
# 436      0.60     -80.03                75.20        9.17
# 473     64.50    -165.41                34.00        8.05
# 514     43.28      -8.21                55.99        1.12

# %%
# Export the index records to be cleaned to a csv file for history purposes
humidity_over100_df.to_csv(output_data_file3)

# %%
# Display before index records total count
toclean_city_weather_df.count()
# Out:
# Weather City           588
# Cloudiness             588
# Country                588
# Date                   588
# Humidity               588
# Latitude               588
# Longitude              588
# Maximum Temperature    588
# Wind Speed             588
# dtype: int64

# %%
# Get the indices of cities that have humidity over 100%.
indexnames=toclean_city_weather_df[toclean_city_weather_df['Humidity']>=100].index
indexnames
# Out:
# Int64Index([67, 84, 92, 100, 101, 137, 182, 210, 238, 278, 307, 329, 406, 436,
#             473, 514],
#            dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
toclean_city_weather_df.drop(indexnames,inplace=True)

# Display before index records total count
toclean_city_weather_df.count()
# Out:
# Weather City           572
# Cloudiness             572
# Country                572
# Date                   572
# Humidity               572
# Latitude               572
# Longitude              572
# Maximum Temperature    572
# Wind Speed             572
# dtype: int64

# %%
# Create new updated and cleaned dataframe
# Export the cleaned City_Data into a csv
cleaned_city_weather_df=toclean_city_weather_df
cleaned_city_weather_df.to_csv(output_data_file2)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
## Scatter plot Latitude vs Temperature - OUTPUT ##
cleaned_city_weather_df.plot(kind="scatter",x="Latitude",y="Maximum Temperature", grid=True,figsize=(8,8))
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.title(f'Weather:  City Latitude vs. Temperature {time.strftime("%m/%d/%Y")}')

# Save chart to file 
plt.savefig("output_data/scatter-plot-chart-latitude-vs-temperature-plot.png") 

plt.show()

## OBSERVATION
## "What's the weather like as we approach the equator?"  (Chart follows explaination)
## Cities closer to the equator have higher temperatures vs. cities that are more south or north of the equator.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
## Scatter plot Latitude vs Humidity - OUTPUT ##
cleaned_city_weather_df.plot(kind="scatter",x="Latitude",y="Humidity", grid=True,figsize=(8,8))
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title(f'Weather:  City Latitude vs. Humidity {time.strftime("%m/%d/%Y")}')

# Save chart to file 
plt.savefig("output_data/scatter-plot-chart-latitude-vs-humidity-plot.png") 

plt.show()

## OBSERVATION
## "What's the weather like as we approach the equator?"  (Chart follows explaination)
## A cities latitude vs humidity does not have any real direct relationship. 
## Though cities sampled seem to be located in areas where the humidity levels on average are at or above 60.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
## Scatter plot Latitude vs Cloudiness - OUTPUT ##
cleaned_city_weather_df.plot(kind="scatter",x="Latitude",y="Cloudiness", grid=True,figsize=(8,8))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title(f'Weather:  City Latitude vs. Cloudiness {time.strftime("%m/%d/%Y")}')

# Save chart to file 
plt.savefig("output_data/scatter-plot-chart-latitude-vs-cloudiness-plot.png") 

plt.show()

## OBSERVATION
## "What's the weather like as we approach the equator?"  (Chart follows explaination)
## A cities cloudiness tends to be more representative of either 0 or 100 (0% clouds vs 100% cloouds) 
## and holds more true in the northern hemisphere. Though this can be just by chance of this sample.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
## Scatter plot Latitude vs Wind Speed - OUTPUT ##
cleaned_city_weather_df.plot(kind="scatter",x="Latitude",y="Wind Speed", grid=True,figsize=(8,8))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title(f'Weather:  City Latitude vs. Wind Speed {time.strftime("%m/%d/%Y")}')

# Save chart to file 
plt.savefig("output_data/scatter-plot-chart-latitude-vs-wind-speed-plot.png") 

plt.show()

## OBSERVATION
## "What's the weather like as we approach the equator?"  (Chart follows explaination)
## A cities latitude vs wind speed there is no strong relationship.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
# for the population of northern and southern hemispheres
x_values = cleaned_city_weather_df['Latitude']
y_values = cleaned_city_weather_df['Maximum Temperature']
plt.scatter(x_values,y_values)

# Calculate Linear Reqression and the r-Squared Value
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")

plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature')
plt.title(f'Weather: City Latitude vs. Maximum Temperature {time.strftime("%m/%d/%Y")}')
plt.show()

## OBSERVATION
## "What's the weather like as we approach the equator?"  (Chart follows explaination)
## Pearson's r-value shows a "week" (r0.3<=r<0.5) relationship between a cities latitude and maximum temperature.
## Visually, cities closer to the equator have higher temperatures vs. cities that are more south or north of the equator.
# Out:
# The r-squared is: 0.4750916218765512

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere_city_weather_df=cleaned_city_weather_df.loc[(cleaned_city_weather_df['Latitude']>=0)]
southern_hemisphere_city_weather_df=cleaned_city_weather_df.loc[(cleaned_city_weather_df['Latitude']<0)]
                           
# Determine quantity of cities in each hemisphere
print("Northern Hemipshere",northern_hemisphere_city_weather_df.count())
print("")
print("Southern Hemipshere",southern_hemisphere_city_weather_df.count())
# Out:
# Northern Hemipshere Weather City           413
# Cloudiness             413
# Country                413
# Date                   413
# Humidity               413
# Latitude               413
# Longitude              413
# Maximum Temperature    413
# Wind Speed             413
# dtype: int64
#
# Southern Hemipshere Weather City           159
# Cloudiness             159
# Country                159
# Date                   159
# Humidity               159
# Latitude               159
# Longitude              159
# Maximum Temperature    159
# Wind Speed             159
# dtype: int64

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
## Scatter plot Latitude vs Temperature - OUTPUT ##
northern_hemisphere_city_weather_df.plot(kind="scatter",x="Latitude",y="Maximum Temperature", grid=True,figsize=(8,8))
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature")
plt.title(f'Northern Hemisphere - Max Temp vs. Latitude {time.strftime("%m/%d/%Y")}')

# Save chart to file 
plt.savefig("output_data/scatter-plot-chart-northern-hemisphere-latitude-vs-temperature-plot.png") 

plt.show()

## OBSERVATION
## "What's the weather like as we approach the equator?"  (Chart follows explaination)
## Visually, cities closer to the equator have higher temperatures vs. cities that are more north of the equator.

# %%
## Northern Hemisphere - Max Temp vs. Latitude Linear Regression - OUTPUT ##

x_values = northern_hemisphere_city_weather_df['Latitude']
y_values = northern_hemisphere_city_weather_df['Maximum Temperature']
plt.scatter(x_values,y_values)

# Calculate Linear Reqression and the r-Squared Value
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")

plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature')
plt.title(f'Northern Hemisphere - Max Temp vs. Latitude Linear Regression {time.strftime("%m/%d/%Y")}')

# Save chart to file 
plt.savefig("output_data/scatter-plot-chart-northern-hemisphere-latitude-vs-temperature-plot-with-linear-regression.png") 

plt.show()

## OBSERVATION
## "What's the weather like as we approach the equator?"  (Chart follows explaination)
## Pearson's r-value shows a "strong" (r>=0.7) relationship between a cities latitude and maximum temperature.
## Visually, cities closer to the equator have higher temperatures vs. cities that are more north of the equator.
# Out:
# The r-squared is: 0.8015190008727371

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
## Scatter plot Latitude vs Temperature - OUTPUT ##
southern_hemisphere_city_weather_df.plot(kind="scatter",x="Latitude",y="Maximum Temperature", grid=True,figsize=(8,8))
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature")
plt.title(f'Southern Hemisphere - Max Temp vs. Latitude {time.strftime("%m/%d/%Y")}')

# Save chart to file 
plt.savefig("output_data/scatter-plot-chart-southern-hemisphere-latitude-vs-temperature-plot.png") 

plt.show()

## OBSERVATION
## "What's the weather like as we approach the equator?"  (Chart follows explaination)
## Visually, cities closer to the equator have higher temperatures vs. cities that are more south of the equator.

# %%
## Southern Hemisphere - Max Temp vs. Latitude Linear Regression - OUTPUT ##

x_values = southern_hemisphere_city_weather_df['Latitude']
y_values = southern_hemisphere_city_weather_df['Maximum Temperature']
plt.scatter(x_values,y_values)

# Calculate Linear Reqression and the r-Squared Value
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")

plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature')
plt.title(f'Southern Hemisphere - Max Temp vs. Latitude Linear Regression {time.strftime("%m/%d/%Y")}')

# Save chart to file 
plt.savefig("output_data/scatter-plot-chart-southern-hemisphere-latitude-vs-temperature-plot-with-linear-regression.png") 

plt.show()

## OBSERVATION
## "What's the weather like as we approach the equator?"  (Chart follows explaination)
## Pearson's r-value shows a "week" (r0.3<=r<0.5) relationship between a cities latitude and maximum temperature.
## Visually, cities closer to the equator have higher temperatures vs. cities that are more south of the equator.
# Out:
# The r-squared is: 0.44820844702700574

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
## Scatter plot Latitude vs Humidity - OUTPUT ##
northern_hemisphere_city_weather_df.plot(kind="scatter",x="Latitude",y="Humidity", grid=True,figsize=(8,8))
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title(f'Northern Hemisphere - Humidity (%) vs. Latitude {time.strftime("%m/%d/%Y")}')

# Save chart to file 
plt.savefig("output_data/scatter-plot-chart-northern-hemisphere-latitude-vs-humidity-plot.png") 

plt.show()

## OBSERVATION
## "What's the weather like as we approach the equator?"  (Chart follows explaination)
## A cities latitude vs humidity does not have any real direct relationship. 
## Though cities sampled seem to be located in areas where the humidity levels on average are at or above 60.

# %%
## Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression - OUTPUT ##

x_values = northern_hemisphere_city_weather_df['Latitude']
y_values = northern_hemisphere_city_weather_df['Humidity']
plt.scatter(x_values,y_values)

# Calculate Linear Reqression and the r-Squared Value
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")

plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(f'Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression {time.strftime("%m/%d/%Y")}')

# Save chart to file 
plt.savefig("output_data/scatter-plot-chart-northern-hemisphere-latitude-vs-humidity-plot-with-linear-regression.png") 

plt.show()

## OBSERVATION
## "What's the weather like as we approach the equator?"  (Chart follows explaination)
## Pearson's r-value shows a "very week" (r<=0.3) relationship between a cities latitude and humidity.
## A cities latitude vs humidity does not have any real direct relationship. 
## Though cities sampled seem to be located in areas where the humidity levels on average are at or above 60.
# Out:
# The r-squared is: 0.11790137390852029

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
## Scatter plot Latitude vs Temperature - OUTPUT ##
southern_hemisphere_city_weather_df.plot(kind="scatter",x="Latitude",y="Humidity", grid=True,figsize=(8,8))
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title(f'Southern Hemisphere - Humidity (%) vs. Latitude {time.strftime("%m/%d/%Y")}')

# Save chart to file 
plt.savefig("output_data/scatter-plot-chart-southern-hemisphere-latitude-vs-humidity-plot.png") 

plt.show()

## OBSERVATION
## "What's the weather like as we approach the equator?"  (Chart follows explaination)
## A cities latitude vs humidity does not have any real direct relationship. 
## Though cities sampled seem to be located in areas where the humidity levels on average are at or above 60 
## and closer to the equator.

# %%
## Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression - OUTPUT ##

x_values = southern_hemisphere_city_weather_df['Latitude']
y_values = southern_hemisphere_city_weather_df['Humidity']
plt.scatter(x_values,y_values)

# Calculate Linear Reqression and the r-Squared Value
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq ="y= "+str(round(slope,2))+"x + "+str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")

plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(f'Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression {time.strftime("%m/%d/%Y")}')

# Save chart to file 
plt.savefig("output_data/scatter-plot-chart-southern-hemisphere-latitude-vs-humidity-plot-with-linear-regression.png") 

plt.show()

## OBSERVATION
## "What's the weather like as we approach the equator?"  (Chart follows explaination)
## Pearson's r-value shows a "very week" (r<=0.3) relationship between a cities latitude and humidity.
## A cities latitude vs humidity does not have any real direct relationship. 
## Though cities sampled seem to be located in areas where the humidity levels on average are at or above 60
## and closer to the equator.
# Out:
# The r-squared is: 0.006622761807777064

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
## Scatter plot Latitude vs Temperature - OUTPUT ##
northern_hemisphere_city_weather_df.plot(kind="scatter",x="Latitude",y="Cloudiness", grid=True,figsize=(8,8))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title(f'Northern Hemisphere - Cloudiness (%) vs. Latitude {time.strftime("%m/%d/%Y")}')

# Save chart to file 
plt.savefig("output_data/scatter-plot-chart-northern-hemisphere-latitude-vs-cloudiness-plot.png") 

plt.show()

## OBSERVATION
## "What's the weather like as we approach the equator?"  (Chart follows explaination)
## A cities latitude vs cloudiness does not have any real direct relationship. 
## A cities cloudiness tends to be more representative of either 0 or 100 (0% clouds vs 100% cloouds) 
## and holds more true in the northern hemisphere. Though this can be just by chance of this sample.

# %%
## Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression - OUTPUT ##

x_values = northern_hemisphere_city_weather_df['Latitude']
y_values = northern_hemisphere_city_weather_df['Cloudiness']
plt.scatter(x_values,y_values)

# Calculate Linear Reqression and the r-Squared Value
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")

plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f'Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression {time.strftime("%m/%d/%Y")}')

# Save chart to file 
plt.savefig("output_data/scatter-plot-chart-northern-hemisphere-latitude-vs-cloudiness-plot-with-linear-regression.png") 

plt.show()

## OBSERVATION
## "What's the weather like as we approach the equator?"  (Chart follows explaination)
## Pearson's r-value shows a "very week" (r<=0.3) relationship between a cities latitude and cloudiness.
## A cities latitude vs cloudiness does not have any real direct relationship. 
## A cities cloudiness tends to be more representative of either 0 or 100 (0% clouds vs 100% cloouds) 
## and holds more true in the northern hemisphere. Though this can be just by chance of this sample.
# Out:
# The r-squared is: 0.0030313249292734834

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
## Scatter plot Latitude vs Temperature - OUTPUT ##
southern_hemisphere_city_weather_df.plot(kind="scatter",x="Latitude",y="Cloudiness", grid=True,figsize=(8,8))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title(f'Southern Hemisphere - Cloudiness (%) vs. Latitude {time.strftime("%m/%d/%Y")}')

# Save chart to file 
plt.savefig("output_data/scatter-plot-chart-southern-hemisphere-latitude-vs-cloudiness-plot.png") 

plt.show()

## OBSERVATION
## "What's the weather like as we approach the equator?"  (Chart follows explaination)
## A cities latitude vs cloudiness does not have any real direct relationship. 
## A cities cloudiness tends to be more representative of either 0 or 100 (0% clouds vs 100% cloouds) 
## and holds more true in the northern vs southern hemisphere. Though this can be just by chance of this sample.

# %%
## Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression - OUTPUT ##

x_values = southern_hemisphere_city_weather_df['Latitude']
y_values = southern_hemisphere_city_weather_df['Cloudiness']
plt.scatter(x_values,y_values)

# Calculate Linear Reqression and the r-Squared Value
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")

plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f'Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression {time.strftime("%m/%d/%Y")}')

# Save chart to file 
plt.savefig("output_data/scatter-plot-chart-southern-hemisphere-latitude-vs-cloudiness-plot-with-linear-regression.png") 

plt.show()

## OBSERVATION
## "What's the weather like as we approach the equator?"  (Chart follows explaination)
## Pearson's r-value shows a "very week" (r<=0.3) relationship between a cities latitude and cloudiness.
## A cities latitude vs cloudiness does not have any real direct relationship. 
## A cities cloudiness tends to be more representative of either 0 or 100 (0% clouds vs 100% cloouds) 
## and holds more true in the northern vs southern hemisphere. Though this can be just by chance of this sample.
# Out:
# The r-squared is: 0.06457888408944398

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
## Scatter plot Latitude vs Temperature - OUTPUT ##
northern_hemisphere_city_weather_df.plot(kind="scatter",x="Latitude",y="Wind Speed", grid=True,figsize=(8,8))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title(f'Northern Hemisphere - Wind Speed (mph) vs. Latitude {time.strftime("%m/%d/%Y")}')

# Save chart to file 
plt.savefig("output_data/scatter-plot-chart-northern-hemisphere-latitude-vs-wind-speed-plot.png") 

plt.show()

## OBSERVATION
## "What's the weather like as we approach the equator?"  (Chart follows explaination)
## A cities latitude vs wind speed there is no strong relationship.

# %%
## Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression - OUTPUT ##

x_values = northern_hemisphere_city_weather_df['Latitude']
y_values = northern_hemisphere_city_weather_df['Wind Speed']
plt.scatter(x_values,y_values)

# Calculate Linear Reqression and the r-Squared Value
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")

plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title(f'Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression {time.strftime("%m/%d/%Y")}')

# Save chart to file 
plt.savefig("output_data/scatter-plot-chart-northern-hemisphere-latitude-vs-wind-speed-plot-with-linear-regression.png") 

plt.show()

## OBSERVATION
## "What's the weather like as we approach the equator?"  (Chart follows explaination)
## Pearson's r-value shows a "very week" (r<=0.3) relationship between a cities latitude and wind speed.
## A cities latitude vs wind speed there is no strong relationship.
# Out:
# The r-squared is: 0.024116570246112738

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
## Scatter plot Latitude vs Temperature - OUTPUT ##
southern_hemisphere_city_weather_df.plot(kind="scatter",x="Latitude",y="Wind Speed", grid=True,figsize=(8,8))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title(f'Southern Hemisphere - Wind Speed (mph) vs. Latitude {time.strftime("%m/%d/%Y")}')

# Save chart to file 
plt.savefig("output_data/scatter-plot-chart-southern-hemisphere-latitude-vs-wind-speed-plot.png") 

plt.show()

## OBSERVATION
## "What's the weather like as we approach the equator?"  (Chart follows explaination)
## A cities latitude vs wind speed there is no strong relationship.

# %%
## Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression - OUTPUT ##

x_values = southern_hemisphere_city_weather_df['Latitude']
y_values = southern_hemisphere_city_weather_df['Wind Speed']
plt.scatter(x_values,y_values)

# Calculate Linear Reqression and the r-Squared Value
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")

plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title(f'Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression {time.strftime("%m/%d/%Y")}')

# Save chart to file 
plt.savefig("output_data/scatter-plot-chart-southern-hemisphere-latitude-vs-wind-speed-plot-with-linear-regression.png") 

plt.show()

## OBSERVATION
## "What's the weather like as we approach the equator?"  (Chart follows explaination)
## Pearson's r-value shows a "very week" (r<=0.3) relationship between a cities latitude and wind speed.
## A cities latitude vs wind speed there is no strong relationship.
# Out:
# The r-squared is: 0.11736724322796849

# %%
## ---EOF--- ##
