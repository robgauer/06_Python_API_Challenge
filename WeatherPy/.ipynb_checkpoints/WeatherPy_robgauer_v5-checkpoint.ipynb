# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
## HEADER COMMENTS
## Python-API-Challenge-WeatherPy-Homework
## Date Due April 18, 2020
## Author:  Rob Gauer

## FILE NAME: WeatherPy.ipynb 
## VERSION: 

## DESCRIPTION
# Part I - WeatherPy
# In this example, you'll be creating a Python script to visualize the weather of 500+ cities 
# across the world of varying distance from the equator. To accomplish this, you'll be utilizing
# a simple Python library, the OpenWeatherMap API, and a little common sense to create 
# a representative model of weather across world cities.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
import random

# Import API key
from api_keys import weather_api_key
from api_keys import g_key

# Incorporated citipy to determine city based on latitude and longitude
# Remember to validate that via pip list that citipy module is installed
from citipy import citipy

# Validate import of api_keys
print("Weather API key is:  "+ weather_api_key)
print("Google API key is:  "+ g_key)

# Read output csv file example and review requirements
#print("")
#print("cities_df Count() INFORMATION")
#print(cities_df.count())
#print("")
#cities_df.head()

# Output Files (CSV)
output_data_file = "output_data/cities.csv"
output_data_file2 = "output_data/cities-cleaned.csv"
output_data_file3 = "output_data/cities-removed-humidity-over-100.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Initialization and define URL to obtain data query end-points
units="imperial"
count_loop=0
loop_set=1
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={units}&q="
#query_url="http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units={units}"
print(query_url)
# Out:
# Weather API key is:  7353f39050ebd58b7f2079c24baa85f5
# Google API key is:  AIzaSyCumrh6DyKgJ9W-WyUggsCVKko9Gbvk9b4
# http://api.openweathermap.org/data/2.5/weather?appid=7353f39050ebd58b7f2079c24baa85f5&units=imperial&q=

# %% [markdown]
# ## Generate Cities List

# %%
## GENERATE CITIES LIST
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
    
# Create a set of random lat and lng combinations
#lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
#lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lats = np.random.uniform(low=-90.000,high=90.000,size=1500)
lngs = np.random.uniform(low=-180.000,high=180.000,size=1500)
lat_lngs = zip(lats,lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city=citipy.nearest_city(lat_lng[0],lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))

# Weather dataframe formatting
city_format={"City":cities}

# Data frame to store data for cities
city_data_df=pd.DataFrame(city_format)
city_data_df
# Out:
# 601
#                City
# 0          tasiilaq
# 1             hisar
# 2     palabuhanratu
# 3      longyearbyen
# 4         taolanaro
# ..              ...
# 596  east grinstead
# 597   goryachegorsk
# 598    bhawanipatna
# 599      santa cruz
# 600            hall
#
# [601 rows x 1 columns]

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
## PERFORM API CALLS
# List for holding response values
weather_city=[]
cloudiness=[]
country=[]
date=[]
humidity=[]
lat=[]
lng=[]
max_temp=[]
wind_speed=[]

# Loop through cities by api calls to url and populate lists
for city in cities:
    try:
        print(f"Processing Record {count_loop} in Loop Set [{loop_set}|{city}")
        #response=requests.get(query_url+city).json()
        #weather_city.append(response['name'])
        response=requests.get(query_url+city.replace(" ","&")).json()
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
        if count_loop>49:
            count_loop=1
            loop_set+=1
            weather_city.append(city)
            # Add a (sixty-five second) interval between queries to stay within API query limits
            time.sleep(65)
        else:
            count_loop+=1
            weather_city.append(city)
    except:
        print("")
        print("EXCEPTION: City name is not found. Skip to next city...")
        print("")
print("")
print("------------------------------Retrieval Complete------------------------------")
print("")
print("OUTPUT LISTS")
print("")
print(f"Weather City List information is:  {weather_city}")
print("")
print(f"Cloudiness List information is:  {cloudiness}")
print("")
print(f"Country List information is:  {country}")
print("")
print(f"Date List information is:  {date}")
print("")
print(f"Humidities List information is:  {humidity}")
print("")
print(f"Latitude List information is:  {lat}")
print("")
print(f"Longitude List information is:  {lng}")
print("")
print(f"Maximum Temperature List information is:  {max_temp}")
print("")
print(f"Wind Speed List information is:  {wind_speed}")
print("")
print("OUTPUT LISTS COMPLETE")
# Out:
# Processing Record 0 in Loop Set [1|tasiilaq
# Processing Record 1 in Loop Set [1|hisar
# Processing Record 2 in Loop Set [1|palabuhanratu
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 2 in Loop Set [1|longyearbyen
# Processing Record 3 in Loop Set [1|taolanaro
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 3 in Loop Set [1|slave lake
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 3 in Loop Set [1|ushuaia
# Processing Record 4 in Loop Set [1|barrow
# Processing Record 5 in Loop Set [1|punta arenas
# Processing Record 6 in Loop Set [1|rikitea
# Processing Record 7 in Loop Set [1|longido
# Processing Record 8 in Loop Set [1|dikson
# Processing Record 9 in Loop Set [1|okha
# Processing Record 10 in Loop Set [1|codrington
# Processing Record 11 in Loop Set [1|albany
# Processing Record 12 in Loop Set [1|san cristobal
# Processing Record 13 in Loop Set [1|cape town
# Processing Record 14 in Loop Set [1|bull savanna
# Processing Record 15 in Loop Set [1|tsihombe
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 15 in Loop Set [1|mys shmidta
# Processing Record 16 in Loop Set [1|butaritari
# Processing Record 17 in Loop Set [1|busselton
# Processing Record 18 in Loop Set [1|airai
# Processing Record 19 in Loop Set [1|mount isa
# Processing Record 20 in Loop Set [1|kodiak
# Processing Record 21 in Loop Set [1|henties bay
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 21 in Loop Set [1|cornwall
# Processing Record 22 in Loop Set [1|kuching
# Processing Record 23 in Loop Set [1|yellowknife
# Processing Record 24 in Loop Set [1|barawe
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 24 in Loop Set [1|shelburne
# Processing Record 25 in Loop Set [1|susanville
# Processing Record 26 in Loop Set [1|vaini
# Processing Record 27 in Loop Set [1|myitkyina
# Processing Record 28 in Loop Set [1|bardiyah
# Processing Record 29 in Loop Set [1|khatanga
# Processing Record 30 in Loop Set [1|jamestown
# Processing Record 31 in Loop Set [1|kaitangata
# Processing Record 32 in Loop Set [1|hithadhoo
# Processing Record 33 in Loop Set [1|ongandjera
# Processing Record 34 in Loop Set [1|pavilosta
# Processing Record 35 in Loop Set [1|hobart
# Processing Record 36 in Loop Set [1|gusevskiy
# Processing Record 37 in Loop Set [1|biak
# Processing Record 38 in Loop Set [1|beckley
# Processing Record 39 in Loop Set [1|kashi
# Processing Record 40 in Loop Set [1|stepnyak
# Processing Record 41 in Loop Set [1|victoria
# Processing Record 42 in Loop Set [1|tagusao
# Processing Record 43 in Loop Set [1|nizhneyansk
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 43 in Loop Set [1|portoferraio
# Processing Record 44 in Loop Set [1|cherskiy
# Processing Record 45 in Loop Set [1|gurupi
# Processing Record 46 in Loop Set [1|samusu
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 46 in Loop Set [1|lagos
# Processing Record 47 in Loop Set [1|hermanus
# Processing Record 48 in Loop Set [1|ilulissat
# Processing Record 49 in Loop Set [1|port-gentil
# Processing Record 50 in Loop Set [1|arraial do cabo
# Processing Record 1 in Loop Set [2|pachperwa
# Processing Record 2 in Loop Set [2|roebourne
# Processing Record 3 in Loop Set [2|carnarvon
# Processing Record 4 in Loop Set [2|ituni
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 4 in Loop Set [2|new norfolk
# Processing Record 5 in Loop Set [2|punta alta
# Processing Record 6 in Loop Set [2|provideniya
# Processing Record 7 in Loop Set [2|mastic beach
# Processing Record 8 in Loop Set [2|san patricio
# Processing Record 9 in Loop Set [2|puerto ayora
# Processing Record 10 in Loop Set [2|viransehir
# Processing Record 11 in Loop Set [2|la palma
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 11 in Loop Set [2|cidreira
# Processing Record 12 in Loop Set [2|avarua
# Processing Record 13 in Loop Set [2|jinji
# Processing Record 14 in Loop Set [2|port alfred
# Processing Record 15 in Loop Set [2|vila velha
# Processing Record 16 in Loop Set [2|morgan city
# Processing Record 17 in Loop Set [2|okhotsk
# Processing Record 18 in Loop Set [2|mar del plata
# Processing Record 19 in Loop Set [2|chukhloma
# Processing Record 20 in Loop Set [2|saint-philippe
# Processing Record 21 in Loop Set [2|dzhusaly
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 21 in Loop Set [2|lebu
# Processing Record 22 in Loop Set [2|upernavik
# Processing Record 23 in Loop Set [2|kavieng
# Processing Record 24 in Loop Set [2|barentsburg
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 24 in Loop Set [2|kuytun
# Processing Record 25 in Loop Set [2|east london
# Processing Record 26 in Loop Set [2|labuhan
# Processing Record 27 in Loop Set [2|kapaa
# Processing Record 28 in Loop Set [2|mataura
# Processing Record 29 in Loop Set [2|bluff
# Processing Record 30 in Loop Set [2|eureka
# Processing Record 31 in Loop Set [2|dawson creek
# Processing Record 32 in Loop Set [2|karratha
# Processing Record 33 in Loop Set [2|clyde river
# Processing Record 34 in Loop Set [2|saint-pierre
# Processing Record 35 in Loop Set [2|artyk
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 35 in Loop Set [2|kholtoson
# Processing Record 36 in Loop Set [2|nelson bay
# Processing Record 37 in Loop Set [2|port elizabeth
# Processing Record 38 in Loop Set [2|sitka
# Processing Record 39 in Loop Set [2|fort nelson
# Processing Record 40 in Loop Set [2|ust-nera
# Processing Record 41 in Loop Set [2|shimoda
# Processing Record 42 in Loop Set [2|quelimane
# Processing Record 43 in Loop Set [2|nikolskoye
# Processing Record 44 in Loop Set [2|norman wells
# Processing Record 45 in Loop Set [2|alice springs
# Processing Record 46 in Loop Set [2|taganak
# Processing Record 47 in Loop Set [2|northam
# Processing Record 48 in Loop Set [2|sazonovo
# Processing Record 49 in Loop Set [2|treinta y tres
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 49 in Loop Set [2|umm lajj
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 49 in Loop Set [2|sosnovo-ozerskoye
# Processing Record 50 in Loop Set [2|kasongo
# Processing Record 1 in Loop Set [3|chuy
# Processing Record 2 in Loop Set [3|alamosa
# Processing Record 3 in Loop Set [3|belaya gora
# Processing Record 4 in Loop Set [3|esperance
# Processing Record 5 in Loop Set [3|saskylakh
# Processing Record 6 in Loop Set [3|isangel
# Processing Record 7 in Loop Set [3|jatara
# Processing Record 8 in Loop Set [3|attawapiskat
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 8 in Loop Set [3|batagay-alyta
# Processing Record 9 in Loop Set [3|lompoc
# Processing Record 10 in Loop Set [3|toora-khem
# Processing Record 11 in Loop Set [3|hofn
# Processing Record 12 in Loop Set [3|sapa
# Processing Record 13 in Loop Set [3|zyryanovsk
# Processing Record 14 in Loop Set [3|qaanaaq
# Processing Record 15 in Loop Set [3|viligili
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 15 in Loop Set [3|faanui
# Processing Record 16 in Loop Set [3|ternate
# Processing Record 17 in Loop Set [3|baruun-urt
# Processing Record 18 in Loop Set [3|praia da vitoria
# Processing Record 19 in Loop Set [3|castro
# Processing Record 20 in Loop Set [3|grand river south east
# Processing Record 21 in Loop Set [3|ust-tsilma
# Processing Record 22 in Loop Set [3|almeirim
# Processing Record 23 in Loop Set [3|iqaluit
# Processing Record 24 in Loop Set [3|bubaque
# Processing Record 25 in Loop Set [3|petropavlovsk-kamchatskiy
# Processing Record 26 in Loop Set [3|netanya
# Processing Record 27 in Loop Set [3|pafos
# Processing Record 28 in Loop Set [3|lorengau
# Processing Record 29 in Loop Set [3|cururupu
# Processing Record 30 in Loop Set [3|unai
# Processing Record 31 in Loop Set [3|necochea
# Processing Record 32 in Loop Set [3|tiksi
# Processing Record 33 in Loop Set [3|polunochnoye
# Processing Record 34 in Loop Set [3|pevek
# Processing Record 35 in Loop Set [3|dryden
# Processing Record 36 in Loop Set [3|jiddah
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 36 in Loop Set [3|sao filipe
# Processing Record 37 in Loop Set [3|kununurra
# Processing Record 38 in Loop Set [3|solnechnyy
# Processing Record 39 in Loop Set [3|atuona
# Processing Record 40 in Loop Set [3|crotone
# Processing Record 41 in Loop Set [3|lagoa
# Processing Record 42 in Loop Set [3|samarai
# Processing Record 43 in Loop Set [3|college
# Processing Record 44 in Loop Set [3|bilma
# Processing Record 45 in Loop Set [3|severo-kurilsk
# Processing Record 46 in Loop Set [3|saleaula
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 46 in Loop Set [3|tidore
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 46 in Loop Set [3|kalmunai
# Processing Record 47 in Loop Set [3|knysna
# Processing Record 48 in Loop Set [3|vaitupu
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 48 in Loop Set [3|illoqqortoormiut
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 48 in Loop Set [3|hoquiam
# Processing Record 49 in Loop Set [3|kawana waters
# Processing Record 50 in Loop Set [3|bengkulu
# Processing Record 1 in Loop Set [4|gander
# Processing Record 2 in Loop Set [4|ribeira grande
# Processing Record 3 in Loop Set [4|ust-kamchatsk
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 3 in Loop Set [4|ponta do sol
# Processing Record 4 in Loop Set [4|haines junction
# Processing Record 5 in Loop Set [4|kropotkin
# Processing Record 6 in Loop Set [4|lakes entrance
# Processing Record 7 in Loop Set [4|basco
# Processing Record 8 in Loop Set [4|kutina
# Processing Record 9 in Loop Set [4|marcona
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 9 in Loop Set [4|rocha
# Processing Record 10 in Loop Set [4|bykovo
# Processing Record 11 in Loop Set [4|coquimbo
# Processing Record 12 in Loop Set [4|kupang
# Processing Record 13 in Loop Set [4|fortuna
# Processing Record 14 in Loop Set [4|koungou
# Processing Record 15 in Loop Set [4|saryshagan
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 15 in Loop Set [4|bredasdorp
# Processing Record 16 in Loop Set [4|baherden
# Processing Record 17 in Loop Set [4|poli
# Processing Record 18 in Loop Set [4|staroderevyankovskaya
# Processing Record 19 in Loop Set [4|hilo
# Processing Record 20 in Loop Set [4|cockburn town
# Processing Record 21 in Loop Set [4|abnub
# Processing Record 22 in Loop Set [4|burica
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 22 in Loop Set [4|dhamtari
# Processing Record 23 in Loop Set [4|beloha
# Processing Record 24 in Loop Set [4|san quintin
# Processing Record 25 in Loop Set [4|najran
# Processing Record 26 in Loop Set [4|imbituba
# Processing Record 27 in Loop Set [4|north platte
# Processing Record 28 in Loop Set [4|southbridge
# Processing Record 29 in Loop Set [4|havoysund
# Processing Record 30 in Loop Set [4|vangaindrano
# Processing Record 31 in Loop Set [4|yilan
# Processing Record 32 in Loop Set [4|viedma
# Processing Record 33 in Loop Set [4|vaitape
# Processing Record 34 in Loop Set [4|faya
# Processing Record 35 in Loop Set [4|bacuit
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 35 in Loop Set [4|taltal
# Processing Record 36 in Loop Set [4|gulfport
# Processing Record 37 in Loop Set [4|pontianak
# Processing Record 38 in Loop Set [4|padang
# Processing Record 39 in Loop Set [4|lakhimpur
# Processing Record 40 in Loop Set [4|palmer
# Processing Record 41 in Loop Set [4|bela
# Processing Record 42 in Loop Set [4|bima
# Processing Record 43 in Loop Set [4|wulanhaote
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 43 in Loop Set [4|thompson
# Processing Record 44 in Loop Set [4|georgetown
# Processing Record 45 in Loop Set [4|caravelas
# Processing Record 46 in Loop Set [4|mehamn
# Processing Record 47 in Loop Set [4|moose factory
# Processing Record 48 in Loop Set [4|port hardy
# Processing Record 49 in Loop Set [4|rovinj
# Processing Record 50 in Loop Set [4|vestmannaeyjar
# Processing Record 1 in Loop Set [5|bloomington
# Processing Record 2 in Loop Set [5|bambous virieux
# Processing Record 3 in Loop Set [5|bentiu
# Processing Record 4 in Loop Set [5|hamilton
# Processing Record 5 in Loop Set [5|saldanha
# Processing Record 6 in Loop Set [5|chokurdakh
# Processing Record 7 in Loop Set [5|srednekolymsk
# Processing Record 8 in Loop Set [5|saint george
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 8 in Loop Set [5|cap malheureux
# Processing Record 9 in Loop Set [5|ishigaki
# Processing Record 10 in Loop Set [5|salym
# Processing Record 11 in Loop Set [5|neiafu
# Processing Record 12 in Loop Set [5|portland
# Processing Record 13 in Loop Set [5|port hedland
# Processing Record 14 in Loop Set [5|harper
# Processing Record 15 in Loop Set [5|littleton
# Processing Record 16 in Loop Set [5|flagstaff
# Processing Record 17 in Loop Set [5|golden
# Processing Record 18 in Loop Set [5|xichang
# Processing Record 19 in Loop Set [5|izhma
# Processing Record 20 in Loop Set [5|vallenar
# Processing Record 21 in Loop Set [5|ancud
# Processing Record 22 in Loop Set [5|yar-sale
# Processing Record 23 in Loop Set [5|guasdualito
# Processing Record 24 in Loop Set [5|beringovskiy
# Processing Record 25 in Loop Set [5|breytovo
# Processing Record 26 in Loop Set [5|cabo san lucas
# Processing Record 27 in Loop Set [5|hailey
# Processing Record 28 in Loop Set [5|inhambane
# Processing Record 29 in Loop Set [5|cao bang
# Processing Record 30 in Loop Set [5|atyrau
# Processing Record 31 in Loop Set [5|devonport
# Processing Record 32 in Loop Set [5|lanja
# Processing Record 33 in Loop Set [5|kenai
# Processing Record 34 in Loop Set [5|hasaki
# Processing Record 35 in Loop Set [5|awbari
# Processing Record 36 in Loop Set [5|belushya guba
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 36 in Loop Set [5|whitianga
# Processing Record 37 in Loop Set [5|talnakh
# Processing Record 38 in Loop Set [5|vandoeuvre-les-nancy
# Processing Record 39 in Loop Set [5|adrar
# Processing Record 40 in Loop Set [5|klaksvik
# Processing Record 41 in Loop Set [5|quatre cocos
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 41 in Loop Set [5|nardaran
# Processing Record 42 in Loop Set [5|saint anthony
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 42 in Loop Set [5|torbay
# Processing Record 43 in Loop Set [5|nishihara
# Processing Record 44 in Loop Set [5|ballina
# Processing Record 45 in Loop Set [5|neuquen
# Processing Record 46 in Loop Set [5|bonnyville
# Processing Record 47 in Loop Set [5|mahebourg
# Processing Record 48 in Loop Set [5|tuktoyaktuk
# Processing Record 49 in Loop Set [5|zlobin
# Processing Record 50 in Loop Set [5|basoko
# Processing Record 1 in Loop Set [6|skagastrond
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 1 in Loop Set [6|sao joao da barra
# Processing Record 2 in Loop Set [6|laguna
# Processing Record 3 in Loop Set [6|mulege
# Processing Record 4 in Loop Set [6|hibbing
# Processing Record 5 in Loop Set [6|te anau
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 5 in Loop Set [6|vostok
# Processing Record 6 in Loop Set [6|lasa
# Processing Record 7 in Loop Set [6|vila franca do campo
# Processing Record 8 in Loop Set [6|pangody
# Processing Record 9 in Loop Set [6|samatau
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 9 in Loop Set [6|mount pleasant
# Processing Record 10 in Loop Set [6|arth
# Processing Record 11 in Loop Set [6|kavaratti
# Processing Record 12 in Loop Set [6|bathsheba
# Processing Record 13 in Loop Set [6|lardos
# Processing Record 14 in Loop Set [6|birao
# Processing Record 15 in Loop Set [6|nieuw amsterdam
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 15 in Loop Set [6|ust-kulom
# Processing Record 16 in Loop Set [6|isla mujeres
# Processing Record 17 in Loop Set [6|zhongshu
# Processing Record 18 in Loop Set [6|sola
# Processing Record 19 in Loop Set [6|constantine
# Processing Record 20 in Loop Set [6|russell
# Processing Record 21 in Loop Set [6|ahipara
# Processing Record 22 in Loop Set [6|atar
# Processing Record 23 in Loop Set [6|gorontalo
# Processing Record 24 in Loop Set [6|zhezkazgan
# Processing Record 25 in Loop Set [6|aparecida do taboado
# Processing Record 26 in Loop Set [6|iquique
# Processing Record 27 in Loop Set [6|igra
# Processing Record 28 in Loop Set [6|gat
# Processing Record 29 in Loop Set [6|panaba
# Processing Record 30 in Loop Set [6|aswan
# Processing Record 31 in Loop Set [6|naron
# Processing Record 32 in Loop Set [6|lac-megantic
# Processing Record 33 in Loop Set [6|teya
# Processing Record 34 in Loop Set [6|kwinana
# Processing Record 35 in Loop Set [6|saint-joseph
# Processing Record 36 in Loop Set [6|vanavara
# Processing Record 37 in Loop Set [6|plettenberg bay
# Processing Record 38 in Loop Set [6|half moon bay
# Processing Record 39 in Loop Set [6|hvide sande
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 39 in Loop Set [6|pimentel
# Processing Record 40 in Loop Set [6|linchuan
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 40 in Loop Set [6|tuatapere
# Processing Record 41 in Loop Set [6|kulhudhuffushi
# Processing Record 42 in Loop Set [6|sawtell
# Processing Record 43 in Loop Set [6|nanortalik
# Processing Record 44 in Loop Set [6|buctzotz
# Processing Record 45 in Loop Set [6|jujuy
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 45 in Loop Set [6|new braunfels
# Processing Record 46 in Loop Set [6|wawa
# Processing Record 47 in Loop Set [6|ankpa
# Processing Record 48 in Loop Set [6|bathurst
# Processing Record 49 in Loop Set [6|chapais
# Processing Record 50 in Loop Set [6|tumannyy
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 50 in Loop Set [6|aklavik
# Processing Record 1 in Loop Set [7|maningrida
# Processing Record 2 in Loop Set [7|behbahan
# Processing Record 3 in Loop Set [7|mazagao
# Processing Record 4 in Loop Set [7|thrissur
# Processing Record 5 in Loop Set [7|kruisfontein
# Processing Record 6 in Loop Set [7|anadyr
# Processing Record 7 in Loop Set [7|batemans bay
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 7 in Loop Set [7|dyersburg
# Processing Record 8 in Loop Set [7|culfa
# Processing Record 9 in Loop Set [7|aripuana
# Processing Record 10 in Loop Set [7|aflu
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 10 in Loop Set [7|kattivakkam
# Processing Record 11 in Loop Set [7|banmo
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 11 in Loop Set [7|pattoki
# Processing Record 12 in Loop Set [7|soria
# Processing Record 13 in Loop Set [7|kemi
# Processing Record 14 in Loop Set [7|tezu
# Processing Record 15 in Loop Set [7|ponta delgada
# Processing Record 16 in Loop Set [7|nagapattinam
# Processing Record 17 in Loop Set [7|do gonbadan
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 17 in Loop Set [7|sogdiondon
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 17 in Loop Set [7|vardo
# Processing Record 18 in Loop Set [7|sobolevo
# Processing Record 19 in Loop Set [7|burns lake
# Processing Record 20 in Loop Set [7|sorvag
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 20 in Loop Set [7|narsaq
# Processing Record 21 in Loop Set [7|sokode
# Processing Record 22 in Loop Set [7|sakaiminato
# Processing Record 23 in Loop Set [7|denpasar
# Processing Record 24 in Loop Set [7|mecca
# Processing Record 25 in Loop Set [7|sterling
# Processing Record 26 in Loop Set [7|olga
# Processing Record 27 in Loop Set [7|tromso
# Processing Record 28 in Loop Set [7|touros
# Processing Record 29 in Loop Set [7|rawannawi
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 29 in Loop Set [7|gushikawa
# Processing Record 30 in Loop Set [7|sangar
# Processing Record 31 in Loop Set [7|jiayuguan
# Processing Record 32 in Loop Set [7|krasnyy chikoy
# Processing Record 33 in Loop Set [7|husavik
# Processing Record 34 in Loop Set [7|geraldton
# Processing Record 35 in Loop Set [7|ayan
# Processing Record 36 in Loop Set [7|sibolga
# Processing Record 37 in Loop Set [7|razumnoye
# Processing Record 38 in Loop Set [7|el alto
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 38 in Loop Set [7|lepe
# Processing Record 39 in Loop Set [7|anchorage
# Processing Record 40 in Loop Set [7|sovetskiy
# Processing Record 41 in Loop Set [7|niono
# Processing Record 42 in Loop Set [7|kangaatsiaq
# Processing Record 43 in Loop Set [7|wundanyi
# Processing Record 44 in Loop Set [7|silleda
# Processing Record 45 in Loop Set [7|cilegon
# Processing Record 46 in Loop Set [7|davila
# Processing Record 47 in Loop Set [7|sentyabrskiy
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 47 in Loop Set [7|balykshi
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 47 in Loop Set [7|severo-yeniseyskiy
# Processing Record 48 in Loop Set [7|mori
# Processing Record 49 in Loop Set [7|sevlievo
# Processing Record 50 in Loop Set [7|inta
# Processing Record 1 in Loop Set [8|korem
# Processing Record 2 in Loop Set [8|san carlos de bariloche
# Processing Record 3 in Loop Set [8|bethel
# Processing Record 4 in Loop Set [8|souillac
# Processing Record 5 in Loop Set [8|rosarito
# Processing Record 6 in Loop Set [8|maloy
# Processing Record 7 in Loop Set [8|bargal
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 7 in Loop Set [8|petropavlovka
# Processing Record 8 in Loop Set [8|le port
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 8 in Loop Set [8|guadalupe
# Processing Record 9 in Loop Set [8|deh rawud
# Processing Record 10 in Loop Set [8|sisimiut
# Processing Record 11 in Loop Set [8|cabimas
# Processing Record 12 in Loop Set [8|winnemucca
# Processing Record 13 in Loop Set [8|karagay
# Processing Record 14 in Loop Set [8|ostrovnoy
# Processing Record 15 in Loop Set [8|ajdabiya
# Processing Record 16 in Loop Set [8|alofi
# Processing Record 17 in Loop Set [8|amahai
# Processing Record 18 in Loop Set [8|oshakati
# Processing Record 19 in Loop Set [8|lichinga
# Processing Record 20 in Loop Set [8|grand baie
# Processing Record 21 in Loop Set [8|jurado
# Processing Record 22 in Loop Set [8|ulladulla
# Processing Record 23 in Loop Set [8|panacan
# Processing Record 24 in Loop Set [8|ginda
# Processing Record 25 in Loop Set [8|goure
# Processing Record 26 in Loop Set [8|broome
# Processing Record 27 in Loop Set [8|porto novo
# Processing Record 28 in Loop Set [8|kitimat
# Processing Record 29 in Loop Set [8|katsuura
# Processing Record 30 in Loop Set [8|balabac
# Processing Record 31 in Loop Set [8|maceio
# Processing Record 32 in Loop Set [8|daru
# Processing Record 33 in Loop Set [8|krasnyye chetai
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 33 in Loop Set [8|rena
# Processing Record 34 in Loop Set [8|sulangan
# Processing Record 35 in Loop Set [8|amatenango del valle
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 35 in Loop Set [8|gurlan
# Processing Record 36 in Loop Set [8|constitucion
# Processing Record 37 in Loop Set [8|middletown
# Processing Record 38 in Loop Set [8|mogadishu
# Processing Record 39 in Loop Set [8|riachao das neves
# Processing Record 40 in Loop Set [8|mayo
# Processing Record 41 in Loop Set [8|sakakah
# Processing Record 42 in Loop Set [8|wolmaranstad
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 42 in Loop Set [8|sa kaeo
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 42 in Loop Set [8|carora
# Processing Record 43 in Loop Set [8|ibra
# Processing Record 44 in Loop Set [8|makakilo city
# Processing Record 45 in Loop Set [8|naze
# Processing Record 46 in Loop Set [8|anloga
# Processing Record 47 in Loop Set [8|guaratinga
# Processing Record 48 in Loop Set [8|tamale
# Processing Record 49 in Loop Set [8|port macquarie
# Processing Record 50 in Loop Set [8|nyurba
# Processing Record 1 in Loop Set [9|uusikaupunki
# Processing Record 2 in Loop Set [9|ranong
# Processing Record 3 in Loop Set [9|tabou
# Processing Record 4 in Loop Set [9|illapel
# Processing Record 5 in Loop Set [9|kastrakion
# Processing Record 6 in Loop Set [9|marawi
# Processing Record 7 in Loop Set [9|mgandu
# Processing Record 8 in Loop Set [9|kerrville
# Processing Record 9 in Loop Set [9|liverpool
# Processing Record 10 in Loop Set [9|itatskiy
# Processing Record 11 in Loop Set [9|olafsvik
# Processing Record 12 in Loop Set [9|diffa
# Processing Record 13 in Loop Set [9|tukums
# Processing Record 14 in Loop Set [9|port shepstone
# Processing Record 15 in Loop Set [9|parrita
# Processing Record 16 in Loop Set [9|guaira
# Processing Record 17 in Loop Set [9|kaeo
# Processing Record 18 in Loop Set [9|megion
# Processing Record 19 in Loop Set [9|coos bay
# Processing Record 20 in Loop Set [9|la ronge
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 20 in Loop Set [9|tarkwa
# Processing Record 21 in Loop Set [9|buta
# Processing Record 22 in Loop Set [9|poanas
# Processing Record 23 in Loop Set [9|dashitou
# Processing Record 24 in Loop Set [9|shebunino
# Processing Record 25 in Loop Set [9|kafue
# Processing Record 26 in Loop Set [9|itacarambi
# Processing Record 27 in Loop Set [9|los llanos de aridane
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 27 in Loop Set [9|vao
# Processing Record 28 in Loop Set [9|muisne
# Processing Record 29 in Loop Set [9|tazovskiy
# Processing Record 30 in Loop Set [9|luderitz
# Processing Record 31 in Loop Set [9|rio grande
# Processing Record 32 in Loop Set [9|spring valley
# Processing Record 33 in Loop Set [9|plouzane
# Processing Record 34 in Loop Set [9|tomas oppus
# Processing Record 35 in Loop Set [9|kungurtug
# Processing Record 36 in Loop Set [9|avera
# Processing Record 37 in Loop Set [9|olden
# Processing Record 38 in Loop Set [9|tuy hoa
# Processing Record 39 in Loop Set [9|bontang
# Processing Record 40 in Loop Set [9|preobrazheniye
# Processing Record 41 in Loop Set [9|havre
# Processing Record 42 in Loop Set [9|palana
# Processing Record 43 in Loop Set [9|guangshui
# Processing Record 44 in Loop Set [9|saint-augustin
# Processing Record 45 in Loop Set [9|benjamin aceval
# Processing Record 46 in Loop Set [9|nuuk
# Processing Record 47 in Loop Set [9|vrangel
# Processing Record 48 in Loop Set [9|elliot lake
# Processing Record 49 in Loop Set [9|sai buri
# Processing Record 50 in Loop Set [9|nhulunbuy
# Processing Record 1 in Loop Set [10|bokspits
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 1 in Loop Set [10|comodoro rivadavia
# Processing Record 2 in Loop Set [10|port blair
# Processing Record 3 in Loop Set [10|tawnat
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 3 in Loop Set [10|grindavik
# Processing Record 4 in Loop Set [10|ketchikan
# Processing Record 5 in Loop Set [10|xai-xai
# Processing Record 6 in Loop Set [10|cayenne
# Processing Record 7 in Loop Set [10|berlevag
# Processing Record 8 in Loop Set [10|tanshui
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 8 in Loop Set [10|kumluca
# Processing Record 9 in Loop Set [10|ugoofaaru
# Processing Record 10 in Loop Set [10|riyadh
# Processing Record 11 in Loop Set [10|cosala
# Processing Record 12 in Loop Set [10|yuci
# Processing Record 13 in Loop Set [10|gazojak
# Processing Record 14 in Loop Set [10|amarante do maranhao
# Processing Record 15 in Loop Set [10|flin flon
# Processing Record 16 in Loop Set [10|causapscal
# Processing Record 17 in Loop Set [10|sur
# Processing Record 18 in Loop Set [10|anton lizardo
# Processing Record 19 in Loop Set [10|fairbanks
# Processing Record 20 in Loop Set [10|palora
# Processing Record 21 in Loop Set [10|nosy varika
# Processing Record 22 in Loop Set [10|athabasca
# Processing Record 23 in Loop Set [10|kahului
# Processing Record 24 in Loop Set [10|punta cardon
# Processing Record 25 in Loop Set [10|roma
# Processing Record 26 in Loop Set [10|quezon
# Processing Record 27 in Loop Set [10|nagato
# Processing Record 28 in Loop Set [10|mangaratiba
# Processing Record 29 in Loop Set [10|evensk
# Processing Record 30 in Loop Set [10|hambantota
# Processing Record 31 in Loop Set [10|hami
# Processing Record 32 in Loop Set [10|heihe
# Processing Record 33 in Loop Set [10|maniitsoq
# Processing Record 34 in Loop Set [10|tiarei
# Processing Record 35 in Loop Set [10|dese
# Processing Record 36 in Loop Set [10|gushi
# Processing Record 37 in Loop Set [10|korla
# Processing Record 38 in Loop Set [10|karaul
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 38 in Loop Set [10|sheridan
# Processing Record 39 in Loop Set [10|ornskoldsvik
# Processing Record 40 in Loop Set [10|pacific grove
# Processing Record 41 in Loop Set [10|port lincoln
# Processing Record 42 in Loop Set [10|zhireken
# Processing Record 43 in Loop Set [10|freeport
# Processing Record 44 in Loop Set [10|kloulklubed
# Processing Record 45 in Loop Set [10|ritchie
# Processing Record 46 in Loop Set [10|dingle
# Processing Record 47 in Loop Set [10|kulykivka
# Processing Record 48 in Loop Set [10|jawhar
# Processing Record 49 in Loop Set [10|russkaya polyana
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 49 in Loop Set [10|nefteyugansk
# Processing Record 50 in Loop Set [10|phuket
# Processing Record 1 in Loop Set [11|vilyuysk
# Processing Record 2 in Loop Set [11|dunedin
# Processing Record 3 in Loop Set [11|uwayl
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 3 in Loop Set [11|vung tau
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 3 in Loop Set [11|goderich
# Processing Record 4 in Loop Set [11|la paz
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 4 in Loop Set [11|deerfield
# Processing Record 5 in Loop Set [11|gimbi
# Processing Record 6 in Loop Set [11|pochutla
# Processing Record 7 in Loop Set [11|madison
# Processing Record 8 in Loop Set [11|abatskoye
# Processing Record 9 in Loop Set [11|sindor
# Processing Record 10 in Loop Set [11|bosaso
# Processing Record 11 in Loop Set [11|zhanaozen
# Processing Record 12 in Loop Set [11|bria
# Processing Record 13 in Loop Set [11|tateyama
# Processing Record 14 in Loop Set [11|belize
# Processing Record 15 in Loop Set [11|southbury
# Processing Record 16 in Loop Set [11|gavrilovka vtoraya
# Processing Record 17 in Loop Set [11|amapa
# Processing Record 18 in Loop Set [11|guiratinga
# Processing Record 19 in Loop Set [11|homer
# Processing Record 20 in Loop Set [11|shingu
# Processing Record 21 in Loop Set [11|vizinga
# Processing Record 22 in Loop Set [11|araouane
# Processing Record 23 in Loop Set [11|maputo
# Processing Record 24 in Loop Set [11|pasni
# Processing Record 25 in Loop Set [11|umzimvubu
#
# EXCEPTION: City name is not found. Skip to next city...
#
# Processing Record 25 in Loop Set [11|hay river
# Processing Record 26 in Loop Set [11|xinzhou
# Processing Record 27 in Loop Set [11|luganville
# Processing Record 28 in Loop Set [11|luwuk
# Processing Record 29 in Loop Set [11|east grinstead
# Processing Record 30 in Loop Set [11|goryachegorsk
# Processing Record 31 in Loop Set [11|bhawanipatna
# Processing Record 32 in Loop Set [11|santa cruz
 1.66, 4.61, 11.97, 31.09, 5.82, 11.56, 2.98, 4.47, 5.01, 2.35, 7.2, 7.34, 12.01, 5.95, 9.17, 4.7, 3.49, 0.45, 1.99, 6.02, 6.85, 2.95, 7.94, 4, 11.41, 8.05, 9.17, 4.16, 4.7, 6.93, 16.2, 10.51, 5.82, 5.86, 14.74, 13.24, 5.82, 1.92, 4.7, 4.76, 4.7, 6.29, 13.87, 5.12, 3.22, 5.46, 10.29, 6.93, 3.36, 4.7, 7.54, 11.41, 3.69, 1.01, 10.36, 6.93, 11.59, 10.29, 10.16, 3.76, 20.8, 12.75, 6.78, 5.93, 3.36, 12.75, 6.93, 8.05, 7.67, 4.72, 5.35, 8.05, 4.32, 10.18, 6.69, 4.7, 4.5, 7.2, 18.77, 14.99, 3.76, 25.68, 3.44, 8.05, 4.21, 18.34, 5.35, 3, 13.42, 4, 4.85, 3.78, 9.17, 2.93, 8.34, 4.7, 1.97, 6.87, 8.05, 17.36, 8.05, 1.52, 4.7, 6.93, 6.93, 1.74, 10.29, 2.95, 6.93, 6.96, 5.46, 17.22, 1.88, 6.26, 11.61, 8.05, 10.29, 10.29, 4.83, 5.82, 6.98, 6.13, 4.72, 28.86, 16.11, 6.82, 5.82, 23.04, 5.44, 9.98, 19.46, 5.99, 8.95, 8.14, 2.75, 3.36, 12.82, 2.66, 8.05, 3.36, 2.24, 6.13, 13.91, 17.22, 6.24, 12.75, 2.44, 3.36, 5.93, 7.99, 2.24, 6.78, 13.42, 9.82, 12.75, 4.5, 8.1, 11.16, 9.17, 12.75, 1.99, 4.21, 12.93, 13.87, 15.19, 5.82, 7.45, 8.86, 8.48, 8.95, 2.24, 8.79, 3, 9.73, 9.17, 1.88, 11.41, 16.11, 17.07, 4.9, 4.5, 1.14, 3.4, 4.7, 6.93, 10.29, 9.55, 0.96, 1.81, 4.7, 19.3, 3.96, 5.46, 3.36, 6.8, 1.99, 1.45, 5.03, 0.81, 8.05, 2.33, 5.55, 2.51, 6.93]
#
# OUTPUT LISTS COMPLETE

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
## CONVERT RAW DATA TO DATAFRAME
# create a data frame from defined lists above.
weather_dictionary={
    "Weather City":weather_city,
    "Cloudiness":cloudiness,
    "Country":country,
    "Date":date,
    "Humidity":humidity,
    "Latitude":lat,
    "Longitude":lng,
    "Maximum Temperature":max_temp,
    "Wind Speed":wind_speed
}

#print(weather_dictionary)

# Data frame to store data setup
city_weather_df=pd.DataFrame(weather_dictionary)

# Save output dataframe data to csv file
city_weather_df.to_csv(output_data_file)

# Display dataframe
city_weather_df.head()
# Out:
#    Weather City  Cloudiness Country        Date  Humidity  Latitude  \
# 0      tasiilaq         100      GL  1587152300        92     65.61
# 1         hisar           0      IN  1587152300        44     29.17
# 2  longyearbyen          75      SJ  1587152287        64     78.22
# 3       ushuaia          20      AR  1587152301        30    -54.80
# 4        barrow          90      US  1587152099        85     71.29
#
#    Longitude  Maximum Temperature  Wind Speed
# 0     -37.64                35.94       27.89
# 1      75.72                75.06        6.67
# 2      15.64                33.80        8.05
# 3     -68.30                57.20       17.22
# 4    -156.79                10.40       17.22

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Create new datafrome for the identification and removal humidity values >=100%
toclean_city_weather_df=city_weather_df

# Identify cities with >= 100% humidity from within the dataframe
humidity_over100_df=toclean_city_weather_df.loc[(toclean_city_weather_df['Humidity']>=100)]
humidity_over100_df
                           
# Determine quantity of cities with >= 100% humidity levels
humidity_over100_df.count()
# Out:
# Weather City           9
# Cloudiness             9
# Country                9
# Date                   9
# Humidity               9
# Latitude               9
# Longitude              9
# Maximum Temperature    9
# Wind Speed             9
# dtype: int64

# %%
# Extract the records based on the index values to remove - review list
# Display the records with >= 100% humidity
humidity_over100_df
# Out:
#     Weather City  Cloudiness Country        Date  Humidity  Latitude  \
# 163      fortuna          90      US  1587152540       100     40.60
# 167         poli          75      TZ  1587152540       100     -3.33
# 221        ancud          90      CL  1587152391       100    -41.87
# 244      ballina          65      AU  1587152625       100    -28.87
# 449     sai buri          16      FR  1587152921       100     48.74
# 456      cayenne          99      GF  1587152672       100      4.93
# 480   hambantota          20      LK  1587152483       100      6.12
# 500       phuket          75      TH  1587153002       100      8.00
# 527   luganville          75      VU  1587152886       100    -15.53
#
#      Longitude  Maximum Temperature  Wind Speed
# 163    -124.16                55.00        9.17
# 167      36.80                71.60        5.82
# 221     -73.82                60.80        9.17
# 244     153.57                69.80        5.82
# 449       0.03                60.01        5.82
# 456     -52.33                75.20        5.82
# 480      81.12                78.80        2.24
# 500      98.25                77.00        2.24
# 527     167.17                73.40        5.03

# %%
# Export the index records to be cleaned to a csv file for history purposes
humidity_over100_df.to_csv(output_data_file3)

# %%
# Display before index records total count
toclean_city_weather_df.count()
# Out:
# Weather City           534
# Cloudiness             534
# Country                534
# Date                   534
# Humidity               534
# Latitude               534
# Longitude              534
# Maximum Temperature    534
# Wind Speed             534
# dtype: int64

# %%
# Get the indices of cities that have humidity over 100%.
indexnames=toclean_city_weather_df[toclean_city_weather_df['Humidity']>=100].index
indexnames
# Out:
# Int64Index([163, 167, 221, 244, 449, 456, 480, 500, 527], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
toclean_city_weather_df.drop(indexnames,inplace=True)

# Display before index records total count
toclean_city_weather_df.count()
# Out:
# Weather City           525
# Cloudiness             525
# Country                525
# Date                   525
# Humidity               525
# Latitude               525
# Longitude              525
# Maximum Temperature    525
# Wind Speed             525
# dtype: int64

# %%
# Create new updated and cleaned dataframe
# Export the cleaned City_Data into a csv
cleaned_city_weather_df=toclean_city_weather_df
cleaned_city_weather_df.to_csv(output_data_file2)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
## Scatter plot Latitude vs Temperature - OUTPUT ##
cleaned_city_weather_df.plot(kind="scatter",x="Latitude",y="Maximum Temperature", grid=True,figsize=(8,8))
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.title(f'Weather:  City Latitude vs. Temperature {time.strftime("%m/%d/%Y")}')

# Save chart to file 
plt.savefig("output_data/scatter-plot-chart-latitude-vs-temperature-plot.png") 

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
## Scatter plot Latitude vs Humidity - OUTPUT ##
cleaned_city_weather_df.plot(kind="scatter",x="Latitude",y="Humidity", grid=True,figsize=(8,8))
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title(f'Weather:  City Latitude vs. Humidity {time.strftime("%m/%d/%Y")}')

# Save chart to file 
plt.savefig("output_data/scatter-plot-chart-latitude-vs-humidity-plot.png") 

plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
## Scatter plot Latitude vs Cloudiness - OUTPUT ##
cleaned_city_weather_df.plot(kind="scatter",x="Latitude",y="Cloudiness", grid=True,figsize=(8,8))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title(f'Weather:  City Latitude vs. Cloudiness {time.strftime("%m/%d/%Y")}')

# Save chart to file 
plt.savefig("output_data/scatter-plot-chart-latitude-vs-cloudiness-plot.png") 

plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
## Scatter plot Latitude vs Wind Speed - OUTPUT ##
cleaned_city_weather_df.plot(kind="scatter",x="Latitude",y="Wind Speed", grid=True,figsize=(8,8))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title(f'Weather:  City Latitude vs. Wind Speed {time.strftime("%m/%d/%Y")}')

# Save chart to file 
plt.savefig("output_data/scatter-plot-chart-latitude-vs-wind-speed-plot.png") 

plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
